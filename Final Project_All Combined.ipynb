# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

from math import sqrt

from scipy import stats

from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller, kpss, grangercausalitytests
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.stats.stattools import durbin_watson

from keras.models import Sequential
from keras.layers import LSTM, Dense, Bidirectional
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau

from itertools import combinations

from datetime import datetime

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
# Out:
# WARNING:tensorflow:From C:\Users\LENOVO\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Loading the data

# %%
data = pd.read_excel('Data.xlsx')

# %% [markdown]
# # Adding date column and making it the index

# %%
# Convert 'Year' and 'Month' to a datetime format
data['Date'] = pd.to_datetime(data['Year'].astype(str) + ' ' + data['Month'], format='%Y %b')

# Drop the original 'Year' and 'Month' columns as they are now redundant
data.drop(['Year', 'Month'], axis=1, inplace=True)

# %%
# Set the 'Date' column as the index of the DataFrame
data.set_index('Date', inplace=True)

# %%
data
# Out:
#             Unemployment Rate (Percent)  \
# Date
# 2000-12-01                          3.9
# 2001-01-01                          4.2
# 2001-02-01                          4.2
# 2001-03-01                          4.3
# 2001-04-01                          4.4
# ...                                 ...
# 2023-08-01                          3.8
# 2023-09-01                          3.8
# 2023-10-01                          3.8
# 2023-11-01                          3.7
# 2023-12-01                          3.7
#
#             Civilian Labor Force (Thousands of people)  \
# Date
# 2000-12-01                                      143248
# 2001-01-01                                      143800
# 2001-02-01                                      143701
# 2001-03-01                                      143924
# 2001-04-01                                      143569
# ...                                                ...
# 2023-08-01                                      167840
# 2023-09-01                                      167897
# 2023-10-01                                      167723
# 2023-11-01                                      168127
# 2023-12-01                                      167451
#
#             Hires level (Thousands of people)  \
# Date
# 2000-12-01                               5426
# 2001-01-01                               5722
# 2001-02-01                               5303
# 2001-03-01                               5528
# 2001-04-01                               5204
# ...                                       ...
# 2023-08-01                               5888
# 2023-09-01                               5851
# 2023-10-01                               5814
# 2023-11-01                               5569
# 2023-12-01                               5787
#
#             Separations level (Thousands of people)  \
# Date
# 2000-12-01                                     5240
# 2001-01-01                                     5842
# 2001-02-01                                     5231
# 2001-03-01                                     5566
# 2001-04-01                                     5414
# ...                                             ...
# 2023-08-01                                     5609
# 2023-09-01                                     5522
# 2023-10-01                                     5630
# 2023-11-01                                     5413
# 2023-12-01                                     5419
#
#             Disposable Personal Income SAAR (Billions of Dollars)  \
# Date
# 2000-12-01                                             7579.4
# 2001-01-01                                             7651.7
# 2001-02-01                                             7672.4
# 2001-03-01                                             7696.3
# 2001-04-01                                             7693.8
# ...                                                       ...
# 2023-08-01                                            20326.4
# 2023-09-01                                            20392.5
# 2023-10-01                                            20437.7
# 2023-11-01                                            20513.5
# 2023-12-01                                            20581.1
#
#             Personal Consumption Expenditures SAAR (Billions of Dollars)  \
# Date
# 2000-12-01                                             6952.2
# 2001-01-01                                             6987.4
# 2001-02-01                                             7001.8
# 2001-03-01                                             6996.7
# 2001-04-01                                             7004.2
# ...                                                       ...
# 2023-08-01                                            18651.6
# 2023-09-01                                            18791.5
# 2023-10-01                                            18826.8
# 2023-11-01                                            18903.0
# 2023-12-01                                            19013.7
#
#             Personal Savings SAAR (Billions of Dollars)  Manufacturing PMI  \
# Date
# 2000-12-01                                        307.2               43.9
# 2001-01-01                                        344.7               42.3
# 2001-02-01                                        350.7               42.1
# 2001-03-01                                        380.1               43.1
# 2001-04-01                                        369.3               42.7
# ...                                                 ...                ...
# 2023-08-01                                        909.4               47.6
# 2023-09-01                                        791.6               49.0
# 2023-10-01                                        814.9               46.7
# 2023-11-01                                        829.7               46.7
# 2023-12-01                                        801.9               47.1
#
#             Manufacturing Employment Index  Services Employment Index  \
# Date
# 2000-12-01                            42.7                       52.4
# 2001-01-01                            42.3                       51.7
# 2001-02-01                            37.8                       50.7
# 2001-03-01                            39.9                       49.6
# 2001-04-01                            38.2                       46.5
# ...                                    ...                        ...
# 2023-08-01                            48.5                       54.7
# 2023-09-01                            51.2                       53.4
# 2023-10-01                            46.8                       50.2
# 2023-11-01                            45.8                       50.7
# 2023-12-01                            47.5                       43.8
#
#             Advance Monthly Sales for retail & food services (Millions of Dollars)  \
# Date
# 2000-12-01                                             275791
# 2001-01-01                                             278834
# 2001-02-01                                             278773
# 2001-03-01                                             276450
# 2001-04-01                                             280808
# ...                                                       ...
# 2023-08-01                                             699540
# 2023-09-01                                             705304
# 2023-10-01                                             703528
# 2023-11-01                                             703336
# 2023-12-01                                             704107
#
#                 CPI
# Date
# 2000-12-01  174.000
# 2001-01-01  175.100
# 2001-02-01  175.800
# 2001-03-01  176.200
# 2001-04-01  176.900
# ...             ...
# 2023-08-01  307.026
# 2023-09-01  307.789
# 2023-10-01  307.671
# 2023-11-01  307.051
# 2023-12-01  306.746
#
# [277 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 277 entries, 2000-12-01 to 2023-12-01
# Data columns (total 12 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   Unemployment Rate (Percent)                                             277 non-null    float64
#  1   Civilian Labor Force (Thousands of people)                              277 non-null    int64
#  2   Hires level (Thousands of people)                                       277 non-null    int64
#  3   Separations level (Thousands of people)                                 277 non-null    int64
#  4   Disposable Personal Income SAAR (Billions of Dollars)                   277 non-null    float64
#  5   Personal Consumption Expenditures SAAR (Billions of Dollars)            277 non-null    float64
#  6   Personal Savings SAAR (Billions of Dollars)                             277 non-null    float64
#  7   Manufacturing PMI                                                       277 non-null    float64
#  8   Manufacturing Employment Index                                          277 non-null    float64
#  9   Services Employment Index                                               277 non-null    float64
#  10  Advance Monthly Sales for retail & food services (Millions of Dollars)  277 non-null    int64
#  11  CPI                                                                     277 non-null    float64
# dtypes: float64(8), int64(4)
# memory usage: 28.1 KB

# %%
data.describe()
# Out:
#        Unemployment Rate (Percent)  \
# count                   277.000000
# mean                      5.834657
# std                       1.977195
# min                       3.400000
# 25%                       4.400000
# 50%                       5.400000
# 75%                       6.700000
# max                      14.800000
#
#        Civilian Labor Force (Thousands of people)  \
# count                                  277.000000
# mean                                155360.057762
# std                                   6292.792545
# min                                 143248.000000
# 25%                                 151716.000000
# 50%                                 154866.000000
# 75%                                 160395.000000
# max                                 168127.000000
#
#        Hires level (Thousands of people)  \
# count                         277.000000
# mean                         5179.776173
# std                           712.346424
# min                          3639.000000
# 25%                          4678.000000
# 50%                          5197.000000
# 75%                          5581.000000
# max                          8136.000000
#
#        Separations level (Thousands of people)  \
# count                               277.000000
# mean                               5088.490975
# std                                 976.882714
# min                                3884.000000
# 25%                                4690.000000
# 50%                                5089.000000
# 75%                                5400.000000
# max                               16805.000000
#
#        Disposable Personal Income SAAR (Billions of Dollars)  \
# count                                         277.000000
# mean                                        12783.964260
# std                                          3551.821532
# min                                          7579.400000
# 25%                                         10018.200000
# 50%                                         12262.100000
# 75%                                         15202.600000
# max                                         21858.100000
#
#        Personal Consumption Expenditures SAAR (Billions of Dollars)  \
# count                                         277.000000
# mean                                        11565.780144
# std                                          3101.712844
# min                                          6952.200000
# 25%                                          9375.400000
# 50%                                         11016.800000
# 75%                                         13703.300000
# max                                         19013.700000
#
#        Personal Savings SAAR (Billions of Dollars)  Manufacturing PMI  \
# count                                   277.000000         277.000000
# mean                                    787.403610          52.729242
# std                                     679.518272           5.341678
# min                                     128.900000          33.300000
# 25%                                     431.200000          50.000000
# 50%                                     690.400000          52.800000
# 75%                                     873.600000          56.600000
# max                                    5976.400000          64.700000
#
#        Manufacturing Employment Index  Services Employment Index  \
# count                      277.000000                 277.000000
# mean                        50.643321                  51.570722
# std                          6.446817                   5.177822
# min                         26.400000                  30.000000
# 25%                         47.500000                  49.100000
# 50%                         51.700000                  52.700000
# 75%                         54.900000                  55.140000
# max                         61.900000                  62.400000
#
#        Advance Monthly Sales for retail & food services (Millions of Dollars)  \
# count                                         277.000000
# mean                                       427630.519856
# std                                        114090.821860
# min                                        275791.000000
# 25%                                        344375.000000
# 50%                                        400155.000000
# 75%                                        490447.000000
# max                                        705304.000000
#
#               CPI
# count  277.000000
# mean   228.592310
# std     33.730685
# min    174.000000
# 25%    202.500000
# 50%    229.601000
# 75%    249.554000
# max    307.789000

# %% [markdown]
# # Analysing the Target Variable

# %%
plt.figure(figsize=(15, 7))
plt.plot(data.index, data['Unemployment Rate (Percent)'], label='Unemployment Rate (Percent)')
plt.title('Unemployment Rate Over Time')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %% [markdown]
# # ACF and PACF plots

# %%
# Plot the ACF
plt.figure(figsize=(12, 6))
plot_acf(data['Unemployment Rate (Percent)'], alpha=0.05, lags=40) 
plt.title('Autocorrelation Function')

# Plot the PACF
plt.figure(figsize=(12, 6))
plot_pacf(data['Unemployment Rate (Percent)'], alpha=0.05, lags=40) 
plt.title('Partial Autocorrelation Function')

plt.show()

# %%
# Perform the Dickey-Fuller test on the 'Unemployment Rate' time series
result = adfuller(data['Unemployment Rate (Percent)'])

# Create a more readable summary of the test
df_output = pd.Series(result[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
for key, value in result[4].items():
    df_output['Critical Value (%s)' % key] = value

print(df_output)
# Out:
# Test Statistic                  -2.892660
# p-value                          0.046208
# #Lags Used                       0.000000
# Number of Observations Used    276.000000
# Critical Value (1%)             -3.454267
# Critical Value (5%)             -2.872070
# Critical Value (10%)            -2.572381
# dtype: float64

# %% [markdown]
# The p-value and test statistic from the Dickey-Fuller test suggest that the series is marginally stationary at a 5% level. However, the time plot and the ACF indicate non-stationarity due to the presence of trends and possibly changing variance. Given the non-stationary visual indicators and the marginal p-value, it's cautious to assume non-stationarity. Therefore, differencing is done.

# %%
data1 = data.copy()

# %%
data1['Differenced_Target'] = data1['Unemployment Rate (Percent)'].diff()

# The first element of the differenced series will be NaN because there is nothing to subtract from the first element
# You can drop the NaN value or fill it if needed
data1 = data1.dropna()

# Plotting the differenced data
data1['Differenced_Target'].plot(figsize=(15, 7), title='Differenced Unemployment Rate Over Time')
plt.xlabel('Time')
plt.ylabel('Differenced Value')
plt.show()

# %%
# Perform the Dickey-Fuller test on the 'Unemployment Rate' time series
result = adfuller(data1['Differenced_Target'])

# Create a more readable summary of the test
df_output = pd.Series(result[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
for key, value in result[4].items():
    df_output['Critical Value (%s)' % key] = value

print(df_output)
# Out:
# Test Statistic                -1.298227e+01
# p-value                        2.926949e-24
# #Lags Used                     1.000000e+00
# Number of Observations Used    2.740000e+02
# Critical Value (1%)           -3.454444e+00
# Critical Value (5%)           -2.872147e+00
# Critical Value (10%)          -2.572422e+00
# dtype: float64

# %% [markdown]
# # Modelling without any exogenous variables

# %% [markdown]
# ACF Plot: Shows a gradual decline, which is typical for an AR process. However, after differencing, if the ACF plot drops off sharply after a lag, this would indicate the number of MA terms.
#
# PACF Plot: Shows a significant spike at lag 1 and cuts off, which suggests an AR(1) process. The spike at lag 1 in the PACF plot typically indicates one AR term.
#
# Based on this information, we can tentatively specify an ARIMA model. Since the data has been differenced once to achieve stationarity, the integrated component (I) is 1. The AR component (p) can be taken as 1 due to the spike in the PACF at lag 1. The MA component (q) can initially be taken as 0 since there is no significant spike in the ACF plot after the first lag that cuts off in the PACF plot.
#
# This leads to an initial ARIMA model of (1,1,0).

# %% [markdown]
# # Model 1 - ARIMA(1,1,0)

# %%
# 1. Split the Data
train_size = int(len(data1) * 0.8)  # 80% for training, 20% for testing
train, test = data1[0:train_size], data1[train_size:]

# 2. Fit the ARIMA Model
# Starting with parameters p=1, d=0, q=1
model = ARIMA(train['Differenced_Target'], order=(1,1,0))
model_fit = model.fit()

# 3. Model Diagnostics
model_fit.plot_diagnostics(figsize=(10, 8))
plt.show()

# 4. Forecasting
forecast = model_fit.get_forecast(steps=len(test))
forecast_mean = forecast.predicted_mean

# Assume 'original_data' contains your entire non-differenced dataset
last_actual_value = data['Unemployment Rate (Percent)'].iloc[-1]  # last value of the original dataset

# Forecast the next three values beyond the test set (as previously described)
total_steps = len(test) + 12
extended_forecast = model_fit.get_forecast(steps=total_steps)
extended_forecast_mean = extended_forecast.predicted_mean

# Dedifference forecast values
# Start with the last actual value from the original data
next_values = [last_actual_value + extended_forecast_mean.iloc[len(test)]]

# Now cumulatively add the forecasted differences to get absolute values
for i in range(1, 12):
    next_value = next_values[i-1] + extended_forecast_mean.iloc[len(test) + i]
    next_values.append(next_value)

print("Dedifferenced forecasted values:")
print(next_values)

# Months (you can replace these with actual month labels)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Plotting the bar chart with annotations
plt.figure(figsize=(10, 6))
bars = plt.bar(months, next_values, color='skyblue')
plt.title('Forecasted Unemployment Rate for Next 12 Months')
plt.xlabel('Months')
plt.ylabel('Unemployment Rate (Percent)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adding value annotations on top of each bar
for bar, value in zip(bars, next_values):
    plt.text(bar.get_x() + bar.get_width() / 2, 
             bar.get_height(), 
             round(value, 2), 
             ha='center', 
             va='bottom')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# Dedifferenced forecasted values:
# [3.6362954851242093, 3.572590970248418, 3.508886455372627, 3.445181940496836, 3.381477425621045, 3.3177729107452536, 3.2540683958694627, 3.1903638809936714, 3.12665936611788, 3.0629548512420888, 2.9992503363662975, 2.935545821490506]

# %%
# Model Evaluation on the differenced scale
mse = mean_squared_error(test['Differenced_Target'], forecast_mean)
rmse = np.sqrt(mse)
mae = mean_absolute_error(test['Differenced_Target'], forecast_mean)
print(f'Mean Absolute Error (MAE): {mae}')
print(f'The Mean Squared Error of the forecasts is {mse}')
print(f'The Root Mean Squared Error of the forecasts is {rmse}')

# Extract AIC and BIC values
aic = model_fit.aic
bic = model_fit.bic
print(f'AIC: {aic}')
print(f'BIC: {bic}')

# Plotting Actual vs. Predicted values
plt.figure(figsize=(12, 6))
plt.plot(test.index, test['Differenced_Target'], label='Actual Differenced Values', color='blue')
plt.plot(test.index, forecast_mean, label='Predicted Differenced Values', color='orange')
plt.title('Actual vs Predicted Differenced Values')
plt.xlabel('Date')
plt.ylabel('Differenced Unemployment Rate (Percent)')
plt.legend()
plt.show()


# Months (you can replace these with actual month labels)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Plotting the bar chart with annotations
plt.figure(figsize=(10, 6))
bars = plt.bar(months, next_values, color='skyblue')
plt.title('Forecasted Unemployment Rate for Next 12 Months')
plt.xlabel('Months')
plt.ylabel('Unemployment Rate (Percent)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adding value annotations on top of each bar
for bar, value in zip(bars, next_values):
    plt.text(bar.get_x() + bar.get_width() / 2, 
             bar.get_height(), 
             round(value, 2), 
             ha='center', 
             va='bottom')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# Mean Absolute Error (MAE): 0.4462074812478952
# The Mean Squared Error of the forecasts is 2.2023154774176867
# The Root Mean Squared Error of the forecasts is 1.4840200394259124
# AIC: -156.94341394890694
# BIC: -150.16527048927392

# %% [markdown]
# # Model 2 - ARIMA(1,1,1)

# %%
# 2. Fit the second ARIMA Model
# Starting with parameters p=1, d=1, q=1
model2 = ARIMA(train['Differenced_Target'], order=(1,1,1))
model2_fit = model2.fit()

# 3. Model Diagnostics
model2_fit.plot_diagnostics(figsize=(10, 8))
plt.show()

# 4. Forecasting
forecast2 = model2_fit.get_forecast(steps=len(test))
forecast_mean2 = forecast2.predicted_mean

# Assume 'original_data' contains your entire non-differenced dataset
last_actual_value = data['Unemployment Rate (Percent)'].iloc[-1]  # last value of the original dataset

# Forecast the next three values beyond the test set (as previously described)
total_steps = len(test) + 12
extended_forecast = model2_fit.get_forecast(steps=total_steps)
extended_forecast_mean = extended_forecast.predicted_mean

# Dedifference forecast values
# Start with the last actual value from the original data
next_values = [last_actual_value + extended_forecast_mean.iloc[len(test)]]

# Now cumulatively add the forecasted differences to get absolute values
for i in range(1, 12):
    next_value = next_values[i-1] + extended_forecast_mean.iloc[len(test) + i]
    next_values.append(next_value)

print("Dedifferenced forecasted values:")
print(next_values)

# Months (you can replace these with actual month labels)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Plotting the bar chart with annotations
plt.figure(figsize=(10, 6))
bars = plt.bar(months, next_values, color='skyblue')
plt.title('Forecasted Unemployment Rate for Next 12 Months')
plt.xlabel('Months')
plt.ylabel('Unemployment Rate (Percent)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adding value annotations on top of each bar
for bar, value in zip(bars, next_values):
    plt.text(bar.get_x() + bar.get_width() / 2, 
             bar.get_height(), 
             round(value, 2), 
             ha='center', 
             va='bottom')

plt.tight_layout()
plt.show()


# 5. Model Evaluation
mse2 = mean_squared_error(test['Differenced_Target'], forecast_mean2)
rmse2 = np.sqrt(mse2)
mae = mean_absolute_error(test['Differenced_Target'], forecast_mean2)
print(f'Mean Absolute Error (MAE): {mae}')
print(f'The Mean Squared Error of the forecasts is {mse2}')
print(f'The Root Mean Squared Error of the forecasts is {rmse2}')

# Extract AIC and BIC values
aic2 = model2_fit.aic
bic2 = model2_fit.bic
print(f'AIC: {aic2}')
print(f'BIC: {bic2}')

# Plotting Actual vs. Predicted values
plt.figure(figsize=(12, 6))
plt.plot(test.index, test['Differenced_Target'], label='Actual Differenced Values', color='blue')
plt.plot(test.index, forecast_mean2, label='Predicted Differenced Values', color='orange')
plt.title('Actual vs Predicted Differenced Values')
plt.xlabel('Date')
plt.ylabel('Differenced Unemployment Rate (Percent)')
plt.legend()
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# Dedifferenced forecasted values:
# [3.667495797042706, 3.6349915940854114, 3.602487391128117, 3.5699831881708226, 3.537478985213528, 3.504974782256234, 3.4724705792989394, 3.439966376341645, 3.4074621733843506, 3.3749579704270563, 3.342453767469762, 3.3099495645124675]
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# Mean Absolute Error (MAE): 0.4515595779826184
# The Mean Squared Error of the forecasts is 2.199299963851908
# The Root Mean Squared Error of the forecasts is 1.4830036965064881
# AIC: -208.92589363424344
# BIC: -198.75867844479393

# %% [markdown]
# # Exploratory Data Analysis of Exogenous variables

# %%
# Define the target variable
target_variable = 'Unemployment Rate (Percent)'

# Get the list of all variables except the target variable
exogenous_variables = data.columns[data.columns != target_variable]

# Create scatter plots for each exogenous variable against the target variable
for variable in exogenous_variables:
    plt.figure(figsize=(8, 6))
    plt.scatter(data[variable], data[target_variable], alpha=0.5)
    plt.title(f'Scatter Plot: {variable} vs. {target_variable}')
    plt.xlabel(variable)
    plt.ylabel(target_variable)
    plt.grid(True)
    plt.show()

# %%
for variable in exogenous_variables:
    plt.figure(figsize=(15, 7))
    plt.plot(data.index, data[variable], label=variable)
    plt.title(variable)
    plt.xlabel('Time')
    plt.ylabel('Value')
    plt.legend()
    plt.show()

# %%
# Calculate the correlation matrix
corr_matrix = data.corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
data_filtered=data.copy()

# %%
data_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 277 entries, 2000-12-01 to 2023-12-01
# Data columns (total 12 columns):
#  #   Column                                                                  Non-Null Count  Dtype
# ---  ------                                                                  --------------  -----
#  0   Unemployment Rate (Percent)                                             277 non-null    float64
#  1   Civilian Labor Force (Thousands of people)                              277 non-null    int64
#  2   Hires level (Thousands of people)                                       277 non-null    int64
#  3   Separations level (Thousands of people)                                 277 non-null    int64
#  4   Disposable Personal Income SAAR (Billions of Dollars)                   277 non-null    float64
#  5   Personal Consumption Expenditures SAAR (Billions of Dollars)            277 non-null    float64
#  6   Personal Savings SAAR (Billions of Dollars)                             277 non-null    float64
#  7   Manufacturing PMI                                                       277 non-null    float64
#  8   Manufacturing Employment Index                                          277 non-null    float64
#  9   Services Employment Index                                               277 non-null    float64
#  10  Advance Monthly Sales for retail & food services (Millions of Dollars)  277 non-null    int64
#  11  CPI                                                                     277 non-null    float64
# dtypes: float64(8), int64(4)
# memory usage: 28.1 KB

# %% [markdown]
# # Drop the mutually correlated columns (to avoid multi collinearity) and columns with no relationship to Unemployment levels

# %%
# Drop the disposable income column as it is causing multicolinearity
data_filtered.drop(['Disposable Personal Income SAAR (Billions of Dollars)','Personal Consumption Expenditures SAAR (Billions of Dollars)','Manufacturing PMI','Manufacturing Employment Index','Advance Monthly Sales for retail & food services (Millions of Dollars)'], axis=1, inplace=True)

# %%
data_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 277 entries, 2000-12-01 to 2023-12-01
# Data columns (total 7 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Unemployment Rate (Percent)                  277 non-null    float64
#  1   Civilian Labor Force (Thousands of people)   277 non-null    int64
#  2   Hires level (Thousands of people)            277 non-null    int64
#  3   Separations level (Thousands of people)      277 non-null    int64
#  4   Personal Savings SAAR (Billions of Dollars)  277 non-null    float64
#  5   Services Employment Index                    277 non-null    float64
#  6   CPI                                          277 non-null    float64
# dtypes: float64(4), int64(3)
# memory usage: 17.3 KB

# %%
# Define the target variable
target_variable = 'Unemployment Rate (Percent)'

# Get the list of all variables except the target variable
exogenous_variables = data_filtered.columns[data_filtered.columns != target_variable]

# %% [markdown]
# # Checking for Stationarity in the exogenous variables

# %%
# Function to run ADF test
def adf_test(series, title=''):
    print(f'Augmented Dickey-Fuller Test: {title}')
    result = adfuller(series.dropna(), autolag='AIC')  # Drop na to avoid invalid computation
    labels = ['ADF test statistic', 'p-value', '# lags', '# observations']
    out = pd.Series(result[0:4], index=labels)

    for key, val in result[4].items():
        out[f'critical value ({key})'] = val
    print(out.to_string())  # .to_string() so it doesn't print in the scientific notation
    
    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non-stationary")
    print("\n")

# Apply the ADF test to each of the exogenous variables
for var in exogenous_variables:
    adf_test(data_filtered[var], title=var)
# Out:
# Augmented Dickey-Fuller Test: Civilian Labor Force (Thousands of people)
# ADF test statistic       -0.547002
# p-value                   0.882514
# # lags                    2.000000
# # observations          274.000000
# critical value (1%)      -3.454444
# critical value (5%)      -2.872147
# critical value (10%)     -2.572422
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
#
#
# Augmented Dickey-Fuller Test: Hires level (Thousands of people)
# ADF test statistic       -1.155007
# p-value                   0.692645
# # lags                    4.000000
# # observations          272.000000
# critical value (1%)      -3.454622
# critical value (5%)      -2.872225
# critical value (10%)     -2.572464
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
#
#
# Augmented Dickey-Fuller Test: Separations level (Thousands of people)
# ADF test statistic       -2.714582
# p-value                   0.071549
# # lags                    7.000000
# # observations          269.000000
# critical value (1%)      -3.454896
# critical value (5%)      -2.872345
# critical value (10%)     -2.572528
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
#
#
# Augmented Dickey-Fuller Test: Personal Savings SAAR (Billions of Dollars)
# ADF test statistic       -2.588239
# p-value                   0.095452
# # lags                   13.000000
# # observations          263.000000
# critical value (1%)      -3.455461
# critical value (5%)      -2.872593
# critical value (10%)     -2.572660
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary
#
#
# Augmented Dickey-Fuller Test: Services Employment Index
# ADF test statistic       -3.947516
# p-value                   0.001712
# # lags                    1.000000
# # observations          275.000000
# critical value (1%)      -3.454355
# critical value (5%)      -2.872108
# critical value (10%)     -2.572401
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
#
# Augmented Dickey-Fuller Test: CPI
# ADF test statistic        0.639540
# p-value                   0.988551
# # lags                   12.000000
# # observations          264.000000
# critical value (1%)      -3.455365
# critical value (5%)      -2.872551
# critical value (10%)     -2.572638
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non-stationary

# %% [markdown]
# # Differencing to make the exogenous variables stationary

# %%
# Differencing the non-stationary variables
data_diff = data_filtered.copy()
data_diff['Hires level (Thousands of people)'] = data_filtered['Hires level (Thousands of people)'].diff()
data_diff['Personal Savings SAAR (Billions of Dollars)'] = data_filtered['Personal Savings SAAR (Billions of Dollars)'].diff()
data_diff['Civilian Labor Force (Thousands of people)'] = data_filtered['Civilian Labor Force (Thousands of people)'].diff()
data_diff['CPI'] = data_filtered['CPI'].diff()
data_diff['Separations level (Thousands of people)'] = data_filtered['Separations level (Thousands of people)'].diff()
data_diff['Unemployment Rate (Percent)'] = data_filtered['Unemployment Rate (Percent)'].diff()

# Drop the first row since differencing will create NaN values
data_diff = data_diff.dropna()

# %%
data_diff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 276 entries, 2001-01-01 to 2023-12-01
# Data columns (total 7 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Unemployment Rate (Percent)                  276 non-null    float64
#  1   Civilian Labor Force (Thousands of people)   276 non-null    float64
#  2   Hires level (Thousands of people)            276 non-null    float64
#  3   Separations level (Thousands of people)      276 non-null    float64
#  4   Personal Savings SAAR (Billions of Dollars)  276 non-null    float64
#  5   Services Employment Index                    276 non-null    float64
#  6   CPI                                          276 non-null    float64
# dtypes: float64(7)
# memory usage: 17.2 KB

# %%
# Apply the ADF test to each of the exogenous variables
for var in exogenous_variables:
    adf_test(data_diff[var], title=var)
# Out:
# Augmented Dickey-Fuller Test: Civilian Labor Force (Thousands of people)
# ADF test statistic     -1.355768e+01
# p-value                 2.342749e-25
# # lags                  1.000000e+00
# # observations          2.740000e+02
# critical value (1%)    -3.454444e+00
# critical value (5%)    -2.872147e+00
# critical value (10%)   -2.572422e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
#
# Augmented Dickey-Fuller Test: Hires level (Thousands of people)
# ADF test statistic     -1.334728e+01
# p-value                 5.761279e-25
# # lags                  3.000000e+00
# # observations          2.720000e+02
# critical value (1%)    -3.454622e+00
# critical value (5%)    -2.872225e+00
# critical value (10%)   -2.572464e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
#
# Augmented Dickey-Fuller Test: Separations level (Thousands of people)
# ADF test statistic     -1.048783e+01
# p-value                 1.167826e-18
# # lags                  6.000000e+00
# # observations          2.690000e+02
# critical value (1%)    -3.454896e+00
# critical value (5%)    -2.872345e+00
# critical value (10%)   -2.572528e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
#
# Augmented Dickey-Fuller Test: Personal Savings SAAR (Billions of Dollars)
# ADF test statistic       -4.736334
# p-value                   0.000072
# # lags                   12.000000
# # observations          263.000000
# critical value (1%)      -3.455461
# critical value (5%)      -2.872593
# critical value (10%)     -2.572660
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
#
# Augmented Dickey-Fuller Test: Services Employment Index
# ADF test statistic       -3.939146
# p-value                   0.001765
# # lags                    1.000000
# # observations          274.000000
# critical value (1%)      -3.454444
# critical value (5%)      -2.872147
# critical value (10%)     -2.572422
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary
#
#
# Augmented Dickey-Fuller Test: CPI
# ADF test statistic       -2.862654
# p-value                   0.049866
# # lags                   11.000000
# # observations          264.000000
# critical value (1%)      -3.455365
# critical value (5%)      -2.872551
# critical value (10%)     -2.572638
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %%
for variable in exogenous_variables:
    plt.figure(figsize=(15, 7))
    plt.plot(data_diff.index, data_diff[variable], label=variable)
    plt.title(variable)
    plt.xlabel('Time')
    plt.ylabel('Value')
    plt.legend()
    plt.show()

# %% [markdown]
# # Modelling with exogenous varibales

# %% [markdown]
# # SARIMAX(1,1,1) with 6 exogenous variables

# %%
# Prepare the exogenous variables (features) and the endogenous variable (target)
exog = data_diff[exogenous_variables]
endog = data_diff[target_variable]

# Split the data into train and test sets
train_size = int(len(data_diff) * 0.8)
train_endog = endog[:train_size]
train_exog = exog[:train_size]
test_endog = endog[train_size:]
test_exog = exog[train_size:]

# Fit the ARIMAX model
model = SARIMAX(train_endog, exog=train_exog, order=(1,1,1))
model_fit = model.fit()

# Summary of the model
print(model_fit.summary())

# Predictions
predictions = model_fit.get_forecast(steps=len(test_endog), exog=test_exog)
predicted_means = predictions.predicted_mean
predicted_intervals = predictions.conf_int()




# Calculate the error metrics
mae = mean_absolute_error(test_endog, predicted_means)
mse = mean_squared_error(test_endog, predicted_means)
rmse = mse**0.5

# Extract AIC and BIC values
aic = model_fit.aic
bic = model_fit.bic
print(f'AIC: {aic}')
print(f'BIC: {bic}')


# Output the error metrics
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Mean Squared Error (MSE): {mse}')
print(f'Root Mean Squared Error (RMSE): {rmse}')
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#                                     SARIMAX Results
# =======================================================================================
# Dep. Variable:     Unemployment Rate (Percent)   No. Observations:                  220
# Model:                        SARIMAX(1, 1, 1)   Log Likelihood                 118.249
# Date:                         Sat, 20 Apr 2024   AIC                           -218.497
# Time:                                 00:15:17   BIC                           -187.995
# Sample:                             01-01-2001   HQIC                          -206.178
#                                   - 04-01-2019
# Covariance Type:                           opg
# ===============================================================================================================
#                                                   coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Civilian Labor Force (Thousands of people)      0.0001   2.33e-05      6.221      0.000    9.91e-05       0.000
# Hires level (Thousands of people)            2.517e-05   8.45e-05      0.298      0.766      -0.000       0.000
# Separations level (Thousands of people)     -5.887e-05   8.52e-05     -0.691      0.490      -0.000       0.000
# Personal Savings SAAR (Billions of Dollars) -7.308e-05    9.3e-05     -0.786      0.432      -0.000       0.000
# Services Employment Index                      -0.0008      0.004     -0.208      0.835      -0.008       0.007
# CPI                                            -0.0229      0.011     -2.002      0.045      -0.045      -0.000
# ar.L1                                          -0.2197      0.107     -2.057      0.040      -0.429      -0.010
# ma.L1                                          -0.6034      0.097     -6.213      0.000      -0.794      -0.413
# sigma2                                          0.0210      0.002      9.080      0.000       0.016       0.025
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.37   Jarque-Bera (JB):                 1.85
# Prob(Q):                              0.24   Prob(JB):                         0.40
# Heteroskedasticity (H):               1.09   Skew:                            -0.20
# Prob(H) (two-sided):                  0.73   Kurtosis:                         3.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# AIC: -218.49713891010134
# BIC: -187.99549334175282
# Mean Absolute Error (MAE): 0.5196467212713825
# Mean Squared Error (MSE): 2.6809735239910735
# Root Mean Squared Error (RMSE): 1.637367864589712
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):

# %%
# Residuals
residuals = model_fit.resid

# Plot residuals
plt.figure(figsize=(10, 6))
plt.plot(residuals)
plt.title('Residuals')
plt.axhline(0, linestyle='--', color='red')
plt.show()

# Histogram of residuals
plt.figure(figsize=(10, 6))
plt.hist(residuals, bins=25)
plt.title('Histogram of Residuals')
plt.show()

# Kernel Density Plot
plt.figure(figsize=(10, 6))
residuals.plot(kind='kde')
plt.title('Kernel Density Plot of Residuals')
plt.show()

# ACF and PACF of residuals
fig, ax = plt.subplots(1, 2, figsize=(15, 6))
plot_acf(residuals, ax=ax[0])
plot_pacf(residuals, ax=ax[1])
plt.show()

# Q-Q plot
fig = sm.qqplot(residuals, line='s')
plt.title('Q-Q Plot of Residuals')
plt.show()

# Ljung-Box Test
lb_test = sm.stats.acorr_ljungbox(residuals, lags=[10], return_df=True)
print(lb_test)

# Durbin-Watson test for autocorrelation

dw = durbin_watson(residuals)
print(f"Durbin-Watson statistic: {dw:.2f}")
# Out:
#       lb_stat  lb_pvalue
# 10  11.526629   0.317985
# Durbin-Watson statistic: 2.17

# %%
# Plotting the actual vs. predicted values for visual comparison
plt.figure(figsize=(10, 5))
plt.plot(test_endog.index, test_endog, label='Actual')
plt.plot(test_endog.index, predicted_means, label='Predicted', color='red')
plt.title('Actual vs Predicted')
plt.xlabel('Date')
plt.ylabel('Unemployment Rate')
plt.legend()
plt.show()

# %% [markdown]
# # Removing exogenous variables with less significance

# %%
data_diff1 = data_diff.copy()


# Drop the insignificant columns
data_diff1.drop(['Hires level (Thousands of people)','Separations level (Thousands of people)','Personal Savings SAAR (Billions of Dollars)','CPI'], axis=1, inplace=True)

# %%
# Define the target variable
target_variable = 'Unemployment Rate (Percent)'

# Get the list of all variables except the target variable
exogenous_variables = data_diff1.columns[data_diff1.columns != target_variable]

# %% [markdown]
# # SARIMAX(1,1,1) with 2 exogenous variables

# %%
# Prepare the exogenous variables (features) and the endogenous variable (target)
exog = data_diff1[exogenous_variables]
endog = data_diff1[target_variable]

# Split the data into train and test sets
train_size = int(len(data_diff1) * 0.8)
train_endog = endog[:train_size]
train_exog = exog[:train_size]
test_endog = endog[train_size:]
test_exog = exog[train_size:]

# Fit the ARIMAX model
model2 = SARIMAX(train_endog, exog=train_exog, order=(1,1,1))
model_fit2 = model2.fit()

# Summary of the model
print(model_fit2.summary())

# Predictions
predictions2 = model_fit2.get_forecast(steps=len(test_endog), exog=test_exog)
predicted_means2 = predictions2.predicted_mean
predicted_intervals2 = predictions2.conf_int()

# Calculate the error metrics
mae2 = mean_absolute_error(test_endog, predicted_means2)
mse2 = mean_squared_error(test_endog, predicted_means2)
rmse2 = mse2**0.5

# Output the error metrics
print(f'Mean Absolute Error (MAE): {mae2}')
print(f'Mean Squared Error (MSE): {mse2}')
print(f'Root Mean Squared Error (RMSE): {rmse2}')

# Extract AIC and BIC values
aic = model_fit2.aic
bic = model_fit2.bic
print(f'AIC: {aic}')
print(f'BIC: {bic}')

# Residuals
residuals2 = model_fit2.resid

# Plot residuals
plt.figure(figsize=(10, 6))
plt.plot(residuals2)
plt.title('Residuals')
plt.axhline(0, linestyle='--', color='red')
plt.show()

# Histogram of residuals
plt.figure(figsize=(10, 6))
plt.hist(residuals2, bins=25)
plt.title('Histogram of Residuals')
plt.show()

# Kernel Density Plot
plt.figure(figsize=(10, 6))
residuals2.plot(kind='kde')
plt.title('Kernel Density Plot of Residuals')
plt.show()

# ACF and PACF of residuals
fig, ax = plt.subplots(1, 2, figsize=(15, 6))
plot_acf(residuals2, ax=ax[0])
plot_pacf(residuals2, ax=ax[1])
plt.show()

# Q-Q plot
fig = sm.qqplot(residuals2, line='s')
plt.title('Q-Q Plot of Residuals')
plt.show()

# Ljung-Box Test
lb_test = sm.stats.acorr_ljungbox(residuals2, lags=[10], return_df=True)
print(lb_test)

# Durbin-Watson test for autocorrelation
dw = durbin_watson(residuals2)
print(f"Durbin-Watson statistic: {dw:.2f}")

# Plotting the actual vs. predicted values for visual comparison
plt.figure(figsize=(10, 5))
plt.plot(test_endog.index, test_endog, label='Actual')
plt.plot(test_endog.index, predicted_means2, label='Predicted', color='red')
plt.title('Actual vs Predicted')
plt.xlabel('Date')
plt.ylabel('Unemployment Rate')
plt.legend()
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#                                     SARIMAX Results
# =======================================================================================
# Dep. Variable:     Unemployment Rate (Percent)   No. Observations:                  220
# Model:                        SARIMAX(1, 1, 1)   Log Likelihood                 120.822
# Date:                         Sat, 20 Apr 2024   AIC                           -231.644
# Time:                                 00:15:20   BIC                           -214.699
# Sample:                             01-01-2001   HQIC                          -224.800
#                                   - 04-01-2019
# Covariance Type:                           opg
# ==============================================================================================================
#                                                  coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# Civilian Labor Force (Thousands of people)     0.0002   2.22e-05      6.767      0.000       0.000       0.000
# Services Employment Index                     -0.0094      0.004     -2.366      0.018      -0.017      -0.002
# ar.L1                                         -0.2294      0.105     -2.187      0.029      -0.435      -0.024
# ma.L1                                         -0.6063      0.097     -6.248      0.000      -0.797      -0.416
# sigma2                                         0.0205      0.002      9.327      0.000       0.016       0.025
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.61   Jarque-Bera (JB):                 2.63
# Prob(Q):                              0.11   Prob(JB):                         0.27
# Heteroskedasticity (H):               1.14   Skew:                            -0.26
# Prob(H) (two-sided):                  0.58   Kurtosis:                         3.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Mean Absolute Error (MAE): 0.5004118391430111
# Mean Squared Error (MSE): 2.5695040439163166
# Root Mean Squared Error (RMSE): 1.602967262272164
# AIC: -231.64400982574116
# BIC: -214.69865117665867
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
#       lb_stat  lb_pvalue
# 10  13.838938   0.180466
# Durbin-Watson statistic: 2.15

# %% [markdown]
# # Comparing Statistical models with Machine Learning Models

# %% [markdown]
# # LSTM(Vanilla)

# %% [markdown]
# # without exogenous variables

# %%
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data_diff1[['Unemployment Rate (Percent)']])

def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX).reshape(-1, look_back, 1), np.array(dataY).reshape(-1, 1)

look_back = 10
X, y = create_dataset(data_scaled, look_back)

train_size = int(len(X) * 0.8)
trainX, testX = X[:train_size], X[train_size:]
trainY, testY = y[:train_size], y[train_size:]

model = Sequential()
model.add(LSTM(50, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(optimizer=Adam(lr=0.01), loss='mean_squared_error')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=0.001)
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2, validation_split=0.2, callbacks=[reduce_lr])


predicted = model.predict(testX)
predicted_rescaled = scaler.inverse_transform(predicted)
testY_rescaled = scaler.inverse_transform(testY)
mse = mean_squared_error(testY_rescaled, predicted_rescaled)
mae = mean_absolute_error(testY_rescaled, predicted_rescaled)
rmse = np.sqrt(mse)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Root Mean Squared Error (RMSE): {rmse}')

plt.figure(figsize=(14, 7))
plt.plot(testY_rescaled, label='Actual', color='blue')
plt.plot(predicted_rescaled, label='Predicted', color='orange')
plt.title('Actual vs Predicted Unemployment Rate')
plt.xlabel('Time Index')
plt.ylabel('Unemployment Rate')
plt.legend()
plt.show()


# Assuming last_sequence is the last part of data_scaled used for forecasting
last_sequence = data_scaled[-look_back:]
current_input = last_sequence.reshape(1, look_back, 1)

predicted_changes = []
for _ in range(12):
    next_difference = model.predict(current_input)
    predicted_changes.append(next_difference.flatten()[0])
    next_difference_reshaped = next_difference.reshape(1, 1, 1)
    current_input = np.append(current_input[:, 1:, :], next_difference_reshaped, axis=1)

predicted_changes_array = np.array(predicted_changes).reshape(-1, 1)
predicted_changes_rescaled = scaler.inverse_transform(predicted_changes_array).flatten()

# Dedifference the predictions
last_actual_value = data['Unemployment Rate (Percent)'].iloc[-1]
dedifferenced_predictions = [last_actual_value + np.sum(predicted_changes_rescaled[:i+1]) for i in range(12)]


print("Dedifferenced forecasted values:")
print(dedifferenced_predictions)

# Months (you can replace these with actual month labels)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Plotting the bar chart with annotations
plt.figure(figsize=(10, 6))
bars = plt.bar(months, dedifferenced_predictions, color='skyblue')
plt.title('Forecasted Unemployment Rate for Next 12 Months')
plt.xlabel('Months')
plt.ylabel('Unemployment Rate (Percent)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adding value annotations on top of each bar
for bar, value in zip(bars, dedifferenced_predictions):
    plt.text(bar.get_x() + bar.get_width() / 2, 
             bar.get_height(), 
             round(value, 2), 
             ha='center', 
             va='bottom')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# WARNING:tensorflow:From C:\Users\LENOVO\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\LENOVO\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From C:\Users\LENOVO\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# 169/169 - 7s - loss: 9.5439e-04 - val_loss: 9.2215e-05 - lr: 0.0010 - 7s/epoch - 40ms/step
# Epoch 2/100
# 169/169 - 1s - loss: 1.7472e-04 - val_loss: 1.4203e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 3/100
# 169/169 - 1s - loss: 1.9682e-04 - val_loss: 9.1757e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 4/100
# 169/169 - 1s - loss: 2.1812e-04 - val_loss: 8.8147e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 5/100
# 169/169 - 1s - loss: 1.8852e-04 - val_loss: 9.7813e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 6/100
# 169/169 - 1s - loss: 2.1250e-04 - val_loss: 2.2313e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 7/100
# 169/169 - 1s - loss: 1.9970e-04 - val_loss: 2.9513e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 8/100
# 169/169 - 1s - loss: 1.8959e-04 - val_loss: 9.8327e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 9/100
# 169/169 - 1s - loss: 1.9562e-04 - val_loss: 1.7033e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 10/100
# 169/169 - 1s - loss: 1.7237e-04 - val_loss: 9.8393e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 11/100
# 169/169 - 1s - loss: 1.7749e-04 - val_loss: 1.4208e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 12/100
# 169/169 - 1s - loss: 1.8073e-04 - val_loss: 1.9904e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 13/100
# 169/169 - 1s - loss: 1.8402e-04 - val_loss: 1.0774e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 14/100
# 169/169 - 1s - loss: 1.7971e-04 - val_loss: 9.3427e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 15/100
# 169/169 - 1s - loss: 1.9034e-04 - val_loss: 1.1464e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 16/100
# 169/169 - 1s - loss: 2.0258e-04 - val_loss: 9.4734e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 17/100
# 169/169 - 1s - loss: 1.9741e-04 - val_loss: 1.1733e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 18/100
# 169/169 - 1s - loss: 1.8507e-04 - val_loss: 9.6045e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 19/100
# 169/169 - 1s - loss: 1.8558e-04 - val_loss: 9.5990e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 20/100
# 169/169 - 1s - loss: 1.8337e-04 - val_loss: 9.8599e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 21/100
# 169/169 - 1s - loss: 1.8358e-04 - val_loss: 1.1887e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 22/100
# 169/169 - 1s - loss: 1.9448e-04 - val_loss: 1.1418e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 23/100
# 169/169 - 1s - loss: 1.8410e-04 - val_loss: 2.4969e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 24/100
# 169/169 - 1s - loss: 1.8014e-04 - val_loss: 2.7030e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 25/100
# 169/169 - 1s - loss: 1.7831e-04 - val_loss: 1.0679e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 26/100
# 169/169 - 1s - loss: 1.8191e-04 - val_loss: 8.9746e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 27/100
# 169/169 - 1s - loss: 1.9516e-04 - val_loss: 1.2635e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 28/100
# 169/169 - 1s - loss: 2.1253e-04 - val_loss: 1.6353e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 29/100
# 169/169 - 1s - loss: 1.7784e-04 - val_loss: 1.4100e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 30/100
# 169/169 - 1s - loss: 1.8339e-04 - val_loss: 1.3272e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 31/100
# 169/169 - 1s - loss: 1.9044e-04 - val_loss: 9.8933e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 32/100
# 169/169 - 1s - loss: 1.9081e-04 - val_loss: 9.5622e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 33/100
# 169/169 - 1s - loss: 1.7170e-04 - val_loss: 1.9449e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 34/100
# 169/169 - 1s - loss: 1.7400e-04 - val_loss: 1.4567e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 35/100
# 169/169 - 1s - loss: 1.9399e-04 - val_loss: 1.2231e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 36/100
# 169/169 - 1s - loss: 1.7746e-04 - val_loss: 1.4044e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 37/100
# 169/169 - 1s - loss: 1.8216e-04 - val_loss: 9.1829e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 38/100
# 169/169 - 1s - loss: 1.8327e-04 - val_loss: 8.8499e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 39/100
# 169/169 - 1s - loss: 1.9571e-04 - val_loss: 9.4500e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 40/100
# 169/169 - 1s - loss: 1.9061e-04 - val_loss: 9.4313e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 41/100
# 169/169 - 1s - loss: 1.7532e-04 - val_loss: 8.8453e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 42/100
# 169/169 - 1s - loss: 1.7887e-04 - val_loss: 8.7856e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 43/100
# 169/169 - 1s - loss: 1.6843e-04 - val_loss: 1.3253e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 44/100
# 169/169 - 1s - loss: 1.7933e-04 - val_loss: 8.9894e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 45/100
# 169/169 - 1s - loss: 1.8098e-04 - val_loss: 1.4257e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 46/100
# 169/169 - 1s - loss: 1.8447e-04 - val_loss: 1.1699e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 47/100
# 169/169 - 1s - loss: 1.8723e-04 - val_loss: 1.2868e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 48/100
# 169/169 - 1s - loss: 1.8036e-04 - val_loss: 1.2051e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 49/100
# 169/169 - 1s - loss: 1.7099e-04 - val_loss: 8.8086e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 50/100
# 169/169 - 1s - loss: 1.8719e-04 - val_loss: 9.0947e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 51/100
# 169/169 - 1s - loss: 1.6417e-04 - val_loss: 9.3705e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 52/100
# 169/169 - 1s - loss: 1.7994e-04 - val_loss: 1.0232e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 53/100
# 169/169 - 1s - loss: 1.6174e-04 - val_loss: 9.1463e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 54/100
# 169/169 - 1s - loss: 1.8241e-04 - val_loss: 9.9407e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 55/100
# 169/169 - 1s - loss: 1.9732e-04 - val_loss: 1.2256e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 56/100
# 169/169 - 1s - loss: 1.7554e-04 - val_loss: 8.6123e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 57/100
# 169/169 - 1s - loss: 1.8091e-04 - val_loss: 1.2238e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 58/100
# 169/169 - 1s - loss: 1.7471e-04 - val_loss: 8.6537e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 59/100
# 169/169 - 1s - loss: 1.7298e-04 - val_loss: 1.0759e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 60/100
# 169/169 - 1s - loss: 1.8789e-04 - val_loss: 1.2145e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 61/100
# 169/169 - 1s - loss: 1.7080e-04 - val_loss: 1.1217e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 62/100
# 169/169 - 1s - loss: 1.6604e-04 - val_loss: 1.2576e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 63/100
# 169/169 - 1s - loss: 1.7021e-04 - val_loss: 9.7410e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 64/100
# 169/169 - 1s - loss: 1.7987e-04 - val_loss: 1.9252e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 65/100
# 169/169 - 1s - loss: 1.7236e-04 - val_loss: 1.7736e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 66/100
# 169/169 - 1s - loss: 1.7837e-04 - val_loss: 8.6943e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 67/100
# 169/169 - 1s - loss: 1.7304e-04 - val_loss: 9.9513e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 68/100
# 169/169 - 1s - loss: 1.8364e-04 - val_loss: 1.3923e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 69/100
# 169/169 - 1s - loss: 1.7423e-04 - val_loss: 1.1988e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 70/100
# 169/169 - 1s - loss: 1.7507e-04 - val_loss: 1.0806e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 71/100
# 169/169 - 1s - loss: 1.6816e-04 - val_loss: 8.5265e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 72/100
# 169/169 - 1s - loss: 1.6618e-04 - val_loss: 1.6893e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 73/100
# 169/169 - 1s - loss: 1.9440e-04 - val_loss: 9.4314e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 74/100
# 169/169 - 1s - loss: 1.9955e-04 - val_loss: 9.9145e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 75/100
# 169/169 - 1s - loss: 1.7454e-04 - val_loss: 1.2762e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 76/100
# 169/169 - 1s - loss: 1.8059e-04 - val_loss: 8.5928e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 77/100
# 169/169 - 1s - loss: 1.7876e-04 - val_loss: 1.1674e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 78/100
# 169/169 - 1s - loss: 1.7032e-04 - val_loss: 1.0424e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 79/100
# 169/169 - 1s - loss: 1.6978e-04 - val_loss: 9.5130e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 80/100
# 169/169 - 1s - loss: 1.7723e-04 - val_loss: 8.7082e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 81/100
# 169/169 - 1s - loss: 1.6949e-04 - val_loss: 8.7626e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 82/100
# 169/169 - 1s - loss: 1.8326e-04 - val_loss: 2.4566e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 83/100
# 169/169 - 1s - loss: 1.8175e-04 - val_loss: 9.5373e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 84/100
# 169/169 - 1s - loss: 1.7155e-04 - val_loss: 1.1424e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 85/100
# 169/169 - 1s - loss: 1.5793e-04 - val_loss: 9.3109e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 86/100
# 169/169 - 1s - loss: 1.8166e-04 - val_loss: 8.8017e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 87/100
# 169/169 - 1s - loss: 1.8003e-04 - val_loss: 1.2144e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 88/100
# 169/169 - 1s - loss: 1.6575e-04 - val_loss: 8.6138e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 89/100
# 169/169 - 1s - loss: 1.6655e-04 - val_loss: 9.8825e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 90/100
# 169/169 - 1s - loss: 1.7002e-04 - val_loss: 2.0119e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 91/100
# 169/169 - 1s - loss: 1.7595e-04 - val_loss: 9.1038e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 92/100
# 169/169 - 1s - loss: 1.6470e-04 - val_loss: 1.7062e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 93/100
# 169/169 - 1s - loss: 1.7491e-04 - val_loss: 9.2604e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 94/100
# 169/169 - 1s - loss: 1.7676e-04 - val_loss: 8.9810e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 95/100
# 169/169 - 1s - loss: 1.6064e-04 - val_loss: 8.5658e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 96/100
# 169/169 - 1s - loss: 1.7307e-04 - val_loss: 1.1305e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 97/100
# 169/169 - 1s - loss: 1.6848e-04 - val_loss: 9.7144e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 98/100
# 169/169 - 1s - loss: 1.6777e-04 - val_loss: 1.4345e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 99/100
# 169/169 - 1s - loss: 1.7068e-04 - val_loss: 1.3930e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 100/100
# 169/169 - 1s - loss: 1.6980e-04 - val_loss: 1.1217e-04 - lr: 0.0010 - 1s/epoch - 7ms/step
# 2/2 [==============================] - 1s 5ms/step
# Mean Squared Error (MSE): 2.5050203016166415
# Mean Absolute Error (MAE): 0.5287385224054257
# Root Mean Squared Error (RMSE): 1.582725592646003
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 46ms/step
# Dedifferenced forecasted values:
# [3.6212469384074213, 3.5304052948951723, 3.427157384157181, 3.3162419617176058, 3.1951566457748415, 3.0661001920700075, 2.934609663486481, 2.798842024803162, 2.6599534273147585, 2.5180261850357057, 2.3748725175857546, 2.2302735567092897]

# %% [markdown]
# # with exogenous variables

# %%
# Data Preparation
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data_diff1[['Unemployment Rate (Percent)', 'Civilian Labor Force (Thousands of people)', 'Services Employment Index']])

# Create dataset for LSTM considering all features
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), :]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY).reshape(-1, 1)

look_back = 10
X, y = create_dataset(data_scaled, look_back)

# Split data into train and test sets
train_size = int(len(X) * 0.8)
trainX, testX = X[:train_size], X[train_size:]
trainY, testY = y[:train_size], y[train_size:]

# LSTM Model with multiple features
model = Sequential()
model.add(LSTM(50, input_shape=(look_back, 3)))  # 3 features
model.add(Dense(1))
model.compile(optimizer=Adam(lr=0.01), loss='mean_squared_error')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=0.001)
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)

# Making predictions
predicted_values = model.predict(testX)

# Revert scaling
testY_rescaled = scaler.inverse_transform(np.hstack([testY, np.zeros((len(testY), 2))]))[:, 0]  # Only reverse scale target
predicted_values_rescaled = scaler.inverse_transform(np.hstack([predicted_values, np.zeros((len(predicted_values), 2))]))[:, 0]

# Calculate error metrics
mse = mean_squared_error(testY_rescaled, predicted_values_rescaled)
mae = mean_absolute_error(testY_rescaled, predicted_values_rescaled)
rmse = np.sqrt(mse)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Root Mean Squared Error (RMSE): {rmse}')

# Plotting actual vs predicted values
plt.figure(figsize=(14, 7))
plt.plot(testY_rescaled, label='Actual', color='blue')
plt.plot(predicted_values_rescaled, label='Predicted LSTM with Exogenous', color='orange')
plt.title('Actual vs Predicted Unemployment Rates')
plt.xlabel('Time Index')
plt.ylabel('Unemployment Rate (Percent)')
plt.legend()
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 212/212 - 5s - loss: 6.3254e-04 - 5s/epoch - 23ms/step
# Epoch 2/100
# 212/212 - 1s - loss: 2.5799e-04 - 1s/epoch - 6ms/step
# Epoch 3/100
# 212/212 - 1s - loss: 1.9083e-04 - 1s/epoch - 6ms/step
# Epoch 4/100
# 212/212 - 1s - loss: 2.2391e-04 - 1s/epoch - 6ms/step
# Epoch 5/100
# 212/212 - 1s - loss: 1.8615e-04 - 1s/epoch - 6ms/step
# Epoch 6/100
# 212/212 - 1s - loss: 1.9487e-04 - 1s/epoch - 6ms/step
# Epoch 7/100
# 212/212 - 1s - loss: 1.7883e-04 - 1s/epoch - 6ms/step
# Epoch 8/100
# 212/212 - 1s - loss: 1.8817e-04 - 1s/epoch - 6ms/step
# Epoch 9/100
# 212/212 - 1s - loss: 2.0123e-04 - 1s/epoch - 6ms/step
# Epoch 10/100
# 212/212 - 1s - loss: 1.5887e-04 - 1s/epoch - 6ms/step
# Epoch 11/100
# 212/212 - 1s - loss: 2.0189e-04 - 1s/epoch - 6ms/step
# Epoch 12/100
# 212/212 - 1s - loss: 1.8709e-04 - 1s/epoch - 7ms/step
# Epoch 13/100
# 212/212 - 1s - loss: 1.5454e-04 - 1s/epoch - 6ms/step
# Epoch 14/100
# 212/212 - 1s - loss: 1.8903e-04 - 1s/epoch - 6ms/step
# Epoch 15/100
# 212/212 - 1s - loss: 1.7979e-04 - 1s/epoch - 6ms/step
# Epoch 16/100
# 212/212 - 1s - loss: 1.8544e-04 - 1s/epoch - 6ms/step
# Epoch 17/100
# 212/212 - 1s - loss: 1.6737e-04 - 1s/epoch - 6ms/step
# Epoch 18/100
# 212/212 - 1s - loss: 1.5619e-04 - 1s/epoch - 6ms/step
# Epoch 19/100
# 212/212 - 1s - loss: 1.5551e-04 - 1s/epoch - 6ms/step
# Epoch 20/100
# 212/212 - 1s - loss: 1.6761e-04 - 1s/epoch - 6ms/step
# Epoch 21/100
# 212/212 - 1s - loss: 1.6928e-04 - 1s/epoch - 6ms/step
# Epoch 22/100
# 212/212 - 1s - loss: 1.8260e-04 - 1s/epoch - 6ms/step
# Epoch 23/100
# 212/212 - 1s - loss: 1.5248e-04 - 1s/epoch - 6ms/step
# Epoch 24/100
# 212/212 - 1s - loss: 1.5921e-04 - 1s/epoch - 6ms/step
# Epoch 25/100
# 212/212 - 1s - loss: 1.9831e-04 - 1s/epoch - 6ms/step
# Epoch 26/100
# 212/212 - 1s - loss: 1.4988e-04 - 1s/epoch - 6ms/step
# Epoch 27/100
# 212/212 - 1s - loss: 1.7755e-04 - 1s/epoch - 7ms/step
# Epoch 28/100
# 212/212 - 1s - loss: 1.5386e-04 - 1s/epoch - 6ms/step
# Epoch 29/100
# 212/212 - 1s - loss: 1.4568e-04 - 1s/epoch - 6ms/step
# Epoch 30/100
# 212/212 - 1s - loss: 1.5103e-04 - 1s/epoch - 6ms/step
# Epoch 31/100
# 212/212 - 1s - loss: 1.7017e-04 - 1s/epoch - 6ms/step
# Epoch 32/100
# 212/212 - 1s - loss: 1.4287e-04 - 1s/epoch - 6ms/step
# Epoch 33/100
# 212/212 - 1s - loss: 1.5583e-04 - 1s/epoch - 6ms/step
# Epoch 34/100
# 212/212 - 1s - loss: 1.3629e-04 - 1s/epoch - 6ms/step
# Epoch 35/100
# 212/212 - 1s - loss: 1.5827e-04 - 1s/epoch - 6ms/step
# Epoch 36/100
# 212/212 - 1s - loss: 1.3924e-04 - 1s/epoch - 6ms/step
# Epoch 37/100
# 212/212 - 1s - loss: 1.3406e-04 - 1s/epoch - 6ms/step
# Epoch 38/100
# 212/212 - 1s - loss: 1.3803e-04 - 1s/epoch - 6ms/step
# Epoch 39/100
# 212/212 - 1s - loss: 1.4185e-04 - 1s/epoch - 6ms/step
# Epoch 40/100
# 212/212 - 1s - loss: 1.4633e-04 - 1s/epoch - 6ms/step
# Epoch 41/100
# 212/212 - 1s - loss: 1.4403e-04 - 1s/epoch - 6ms/step
# Epoch 42/100
# 212/212 - 1s - loss: 1.5805e-04 - 1s/epoch - 6ms/step
# Epoch 43/100
# 212/212 - 1s - loss: 1.4245e-04 - 1s/epoch - 6ms/step
# Epoch 44/100
# 212/212 - 1s - loss: 1.3886e-04 - 1s/epoch - 6ms/step
# Epoch 45/100
# 212/212 - 1s - loss: 1.4266e-04 - 1s/epoch - 6ms/step
# Epoch 46/100
# 212/212 - 1s - loss: 1.2748e-04 - 1s/epoch - 6ms/step
# Epoch 47/100
# 212/212 - 1s - loss: 1.3935e-04 - 1s/epoch - 6ms/step
# Epoch 48/100
# 212/212 - 1s - loss: 1.3574e-04 - 1s/epoch - 6ms/step
# Epoch 49/100
# 212/212 - 1s - loss: 1.3579e-04 - 1s/epoch - 6ms/step
# Epoch 50/100
# 212/212 - 1s - loss: 1.3284e-04 - 1s/epoch - 6ms/step
# Epoch 51/100
# 212/212 - 1s - loss: 1.3367e-04 - 1s/epoch - 6ms/step
# Epoch 52/100
# 212/212 - 1s - loss: 1.4339e-04 - 1s/epoch - 6ms/step
# Epoch 53/100
# 212/212 - 1s - loss: 1.2945e-04 - 1s/epoch - 6ms/step
# Epoch 54/100
# 212/212 - 1s - loss: 1.3436e-04 - 1s/epoch - 6ms/step
# Epoch 55/100
# 212/212 - 1s - loss: 1.4046e-04 - 1s/epoch - 6ms/step
# Epoch 56/100
# 212/212 - 1s - loss: 1.3485e-04 - 1s/epoch - 6ms/step
# Epoch 57/100
# 212/212 - 1s - loss: 1.2552e-04 - 1s/epoch - 6ms/step
# Epoch 58/100
# 212/212 - 1s - loss: 1.3350e-04 - 1s/epoch - 6ms/step
# Epoch 59/100
# 212/212 - 1s - loss: 1.3051e-04 - 1s/epoch - 6ms/step
# Epoch 60/100
# 212/212 - 1s - loss: 1.2301e-04 - 1s/epoch - 6ms/step
# Epoch 61/100
# 212/212 - 1s - loss: 1.3083e-04 - 1s/epoch - 6ms/step
# Epoch 62/100
# 212/212 - 1s - loss: 1.3526e-04 - 1s/epoch - 6ms/step
# Epoch 63/100
# 212/212 - 1s - loss: 1.2837e-04 - 1s/epoch - 6ms/step
# Epoch 64/100
# 212/212 - 1s - loss: 1.3238e-04 - 1s/epoch - 6ms/step
# Epoch 65/100
# 212/212 - 1s - loss: 1.3222e-04 - 1s/epoch - 6ms/step
# Epoch 66/100
# 212/212 - 1s - loss: 1.2736e-04 - 1s/epoch - 6ms/step
# Epoch 67/100
# 212/212 - 1s - loss: 1.2763e-04 - 1s/epoch - 6ms/step
# Epoch 68/100
# 212/212 - 1s - loss: 1.2382e-04 - 1s/epoch - 6ms/step
# Epoch 69/100
# 212/212 - 1s - loss: 1.3638e-04 - 1s/epoch - 6ms/step
# Epoch 70/100
# 212/212 - 1s - loss: 1.3028e-04 - 1s/epoch - 6ms/step
# Epoch 71/100
# 212/212 - 1s - loss: 1.4977e-04 - 1s/epoch - 6ms/step
# Epoch 72/100
# 212/212 - 1s - loss: 1.2800e-04 - 1s/epoch - 6ms/step
# Epoch 73/100
# 212/212 - 1s - loss: 1.2777e-04 - 1s/epoch - 6ms/step
# Epoch 74/100
# 212/212 - 1s - loss: 1.2352e-04 - 1s/epoch - 6ms/step
# Epoch 75/100
# 212/212 - 1s - loss: 1.2845e-04 - 1s/epoch - 6ms/step
# Epoch 76/100
# 212/212 - 1s - loss: 1.2763e-04 - 1s/epoch - 6ms/step
# Epoch 77/100
# 212/212 - 1s - loss: 1.2710e-04 - 1s/epoch - 6ms/step
# Epoch 78/100
# 212/212 - 1s - loss: 1.2163e-04 - 1s/epoch - 6ms/step
# Epoch 79/100
# 212/212 - 1s - loss: 1.2703e-04 - 1s/epoch - 6ms/step
# Epoch 80/100
# 212/212 - 1s - loss: 1.1696e-04 - 1s/epoch - 6ms/step
# Epoch 81/100
# 212/212 - 1s - loss: 1.2512e-04 - 1s/epoch - 6ms/step
# Epoch 82/100
# 212/212 - 1s - loss: 1.2572e-04 - 1s/epoch - 6ms/step
# Epoch 83/100
# 212/212 - 1s - loss: 1.2119e-04 - 1s/epoch - 6ms/step
# Epoch 84/100
# 212/212 - 1s - loss: 1.2499e-04 - 1s/epoch - 6ms/step
# Epoch 85/100
# 212/212 - 1s - loss: 1.2500e-04 - 1s/epoch - 6ms/step
# Epoch 86/100
# 212/212 - 1s - loss: 1.2264e-04 - 1s/epoch - 6ms/step
# Epoch 87/100
# 212/212 - 1s - loss: 1.2530e-04 - 1s/epoch - 6ms/step
# Epoch 88/100
# 212/212 - 1s - loss: 1.2549e-04 - 1s/epoch - 6ms/step
# Epoch 89/100
# 212/212 - 1s - loss: 1.2905e-04 - 1s/epoch - 6ms/step
# Epoch 90/100
# 212/212 - 1s - loss: 1.2956e-04 - 1s/epoch - 6ms/step
# Epoch 91/100
# 212/212 - 1s - loss: 1.1867e-04 - 1s/epoch - 6ms/step
# Epoch 92/100
# 212/212 - 1s - loss: 1.1952e-04 - 1s/epoch - 6ms/step
# Epoch 93/100
# 212/212 - 1s - loss: 1.2286e-04 - 1s/epoch - 6ms/step
# Epoch 94/100
# 212/212 - 1s - loss: 1.2467e-04 - 1s/epoch - 6ms/step
# Epoch 95/100
# 212/212 - 1s - loss: 1.2600e-04 - 1s/epoch - 6ms/step
# Epoch 96/100
# 212/212 - 1s - loss: 1.2950e-04 - 1s/epoch - 5ms/step
# Epoch 97/100
# 212/212 - 1s - loss: 1.1580e-04 - 1s/epoch - 6ms/step
# Epoch 98/100
# 212/212 - 1s - loss: 1.2751e-04 - 1s/epoch - 6ms/step
# Epoch 99/100
# 212/212 - 1s - loss: 1.2285e-04 - 1s/epoch - 6ms/step
# Epoch 100/100
# 212/212 - 1s - loss: 1.2425e-04 - 1s/epoch - 6ms/step
# 2/2 [==============================] - 1s 6ms/step
# Mean Squared Error (MSE): 2.5499744051213384
# Mean Absolute Error (MAE): 0.5347529298573168
# Root Mean Squared Error (RMSE): 1.5968639281796488

# %% [markdown]
# # Bi-LSTM

# %% [markdown]
# # Without exogenous variables

# %%
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data_diff1[['Unemployment Rate (Percent)']])

def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX).reshape(-1, look_back, 1), np.array(dataY).reshape(-1, 1)

look_back = 10
X, y = create_dataset(data_scaled, look_back)

train_size = int(len(X) * 0.8)
trainX, testX = X[:train_size], X[train_size:]
trainY, testY = y[:train_size], y[train_size:]

model = Sequential()
model.add(Bidirectional(LSTM(50, input_shape=(look_back, 1))))
model.add(Dense(1))
model.compile(optimizer=Adam(lr=0.01), loss='mean_squared_error')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=0.001)
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2, validation_split=0.2, callbacks=[reduce_lr])


predicted = model.predict(testX)
predicted_rescaled = scaler.inverse_transform(predicted)
testY_rescaled = scaler.inverse_transform(testY)
mse = mean_squared_error(testY_rescaled, predicted_rescaled)
mae = mean_absolute_error(testY_rescaled, predicted_rescaled)
rmse = np.sqrt(mse)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Root Mean Squared Error (RMSE): {rmse}')

plt.figure(figsize=(14, 7))
plt.plot(testY_rescaled, label='Actual', color='blue')
plt.plot(predicted_rescaled, label='Predicted', color='orange')
plt.title('Actual vs Predicted Unemployment Rates')
plt.xlabel('Time Index')
plt.ylabel('Unemployment Rate')
plt.legend()
plt.show()


# Assuming last_sequence is the last part of data_scaled used for forecasting
last_sequence = data_scaled[-look_back:]
current_input = last_sequence.reshape(1, look_back, 1)

predicted_changes = []
for _ in range(12):
    next_difference = model.predict(current_input)
    predicted_changes.append(next_difference.flatten()[0])
    next_difference_reshaped = next_difference.reshape(1, 1, 1)
    current_input = np.append(current_input[:, 1:, :], next_difference_reshaped, axis=1)

predicted_changes_array = np.array(predicted_changes).reshape(-1, 1)
predicted_changes_rescaled = scaler.inverse_transform(predicted_changes_array).flatten()

# Dedifference the predictions
last_actual_value = data['Unemployment Rate (Percent)'].iloc[-1]
dedifferenced_predictions = [last_actual_value + np.sum(predicted_changes_rescaled[:i+1]) for i in range(12)]


print("Dedifferenced forecasted values:")
print(dedifferenced_predictions)

# Months (you can replace these with actual month labels)
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# Plotting the bar chart with annotations
plt.figure(figsize=(10, 6))
bars = plt.bar(months, dedifferenced_predictions, color='skyblue')
plt.title('Forecasted Unemployment Rate for Next 12 Months')
plt.xlabel('Months')
plt.ylabel('Unemployment Rate (Percent)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adding value annotations on top of each bar
for bar, value in zip(bars, dedifferenced_predictions):
    plt.text(bar.get_x() + bar.get_width() / 2, 
             bar.get_height(), 
             round(value, 2), 
             ha='center', 
             va='bottom')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 169/169 - 11s - loss: 7.0971e-04 - val_loss: 1.2667e-04 - lr: 0.0010 - 11s/epoch - 65ms/step
# Epoch 2/100
# 169/169 - 1s - loss: 1.8599e-04 - val_loss: 8.5625e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 3/100
# 169/169 - 1s - loss: 2.3558e-04 - val_loss: 2.6876e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 4/100
# 169/169 - 1s - loss: 2.2237e-04 - val_loss: 8.8263e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 5/100
# 169/169 - 1s - loss: 1.8694e-04 - val_loss: 9.4076e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 6/100
# 169/169 - 1s - loss: 2.0415e-04 - val_loss: 9.5829e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 7/100
# 169/169 - 1s - loss: 1.8839e-04 - val_loss: 1.2945e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 8/100
# 169/169 - 1s - loss: 1.7509e-04 - val_loss: 9.5862e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 9/100
# 169/169 - 1s - loss: 1.9495e-04 - val_loss: 1.4619e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 10/100
# 169/169 - 1s - loss: 2.1343e-04 - val_loss: 1.7055e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 11/100
# 169/169 - 1s - loss: 2.3299e-04 - val_loss: 9.6920e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 12/100
# 169/169 - 1s - loss: 1.9045e-04 - val_loss: 9.3696e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 13/100
# 169/169 - 1s - loss: 1.7701e-04 - val_loss: 3.7466e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 14/100
# 169/169 - 1s - loss: 2.1383e-04 - val_loss: 9.6430e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 15/100
# 169/169 - 1s - loss: 1.8919e-04 - val_loss: 8.8199e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 16/100
# 169/169 - 1s - loss: 2.0129e-04 - val_loss: 1.0474e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 17/100
# 169/169 - 1s - loss: 1.7959e-04 - val_loss: 9.6210e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 18/100
# 169/169 - 1s - loss: 2.0123e-04 - val_loss: 9.5987e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 19/100
# 169/169 - 1s - loss: 2.0586e-04 - val_loss: 1.3655e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 20/100
# 169/169 - 1s - loss: 1.8156e-04 - val_loss: 8.6866e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 21/100
# 169/169 - 1s - loss: 1.7419e-04 - val_loss: 8.8366e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 22/100
# 169/169 - 1s - loss: 1.9781e-04 - val_loss: 8.7470e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 23/100
# 169/169 - 1s - loss: 1.7592e-04 - val_loss: 9.2706e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 24/100
# 169/169 - 1s - loss: 1.8123e-04 - val_loss: 8.7305e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 25/100
# 169/169 - 1s - loss: 1.6885e-04 - val_loss: 1.0521e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 26/100
# 169/169 - 1s - loss: 1.9576e-04 - val_loss: 9.8941e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 27/100
# 169/169 - 1s - loss: 1.8811e-04 - val_loss: 9.9567e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 28/100
# 169/169 - 1s - loss: 1.7267e-04 - val_loss: 3.1827e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 29/100
# 169/169 - 1s - loss: 2.0177e-04 - val_loss: 1.0217e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 30/100
# 169/169 - 1s - loss: 1.8200e-04 - val_loss: 1.1250e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 31/100
# 169/169 - 1s - loss: 1.8101e-04 - val_loss: 1.1713e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 32/100
# 169/169 - 1s - loss: 1.8107e-04 - val_loss: 1.1708e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 33/100
# 169/169 - 1s - loss: 1.7872e-04 - val_loss: 5.4857e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 34/100
# 169/169 - 1s - loss: 1.9870e-04 - val_loss: 8.7340e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 35/100
# 169/169 - 1s - loss: 1.9815e-04 - val_loss: 8.6814e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 36/100
# 169/169 - 1s - loss: 2.1162e-04 - val_loss: 1.3103e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 37/100
# 169/169 - 1s - loss: 1.7576e-04 - val_loss: 9.9249e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 38/100
# 169/169 - 1s - loss: 1.7085e-04 - val_loss: 9.8763e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 39/100
# 169/169 - 1s - loss: 1.7558e-04 - val_loss: 8.8653e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 40/100
# 169/169 - 1s - loss: 1.6544e-04 - val_loss: 1.0408e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 41/100
# 169/169 - 1s - loss: 1.7839e-04 - val_loss: 1.0479e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 42/100
# 169/169 - 1s - loss: 1.7782e-04 - val_loss: 2.3368e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 43/100
# 169/169 - 1s - loss: 1.9207e-04 - val_loss: 1.4281e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 44/100
# 169/169 - 1s - loss: 1.9430e-04 - val_loss: 9.5070e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 45/100
# 169/169 - 1s - loss: 1.6803e-04 - val_loss: 9.1259e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 46/100
# 169/169 - 1s - loss: 1.9392e-04 - val_loss: 8.7517e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 47/100
# 169/169 - 1s - loss: 1.7454e-04 - val_loss: 8.8449e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 48/100
# 169/169 - 1s - loss: 1.6885e-04 - val_loss: 8.9817e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 49/100
# 169/169 - 1s - loss: 1.9395e-04 - val_loss: 8.8364e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 50/100
# 169/169 - 1s - loss: 1.8653e-04 - val_loss: 1.1311e-04 - lr: 0.0010 - 1s/epoch - 9ms/step
# Epoch 51/100
# 169/169 - 1s - loss: 1.9274e-04 - val_loss: 8.8069e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 52/100
# 169/169 - 1s - loss: 1.9660e-04 - val_loss: 9.5033e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 53/100
# 169/169 - 1s - loss: 1.9338e-04 - val_loss: 9.2411e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 54/100
# 169/169 - 1s - loss: 1.6772e-04 - val_loss: 8.7086e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 55/100
# 169/169 - 1s - loss: 1.7592e-04 - val_loss: 8.8649e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 56/100
# 169/169 - 1s - loss: 1.7792e-04 - val_loss: 8.8746e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 57/100
# 169/169 - 1s - loss: 1.6939e-04 - val_loss: 4.0661e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 58/100
# 169/169 - 1s - loss: 1.7740e-04 - val_loss: 9.3503e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 59/100
# 169/169 - 1s - loss: 1.8485e-04 - val_loss: 1.4487e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 60/100
# 169/169 - 1s - loss: 1.7196e-04 - val_loss: 8.5920e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 61/100
# 169/169 - 1s - loss: 1.7387e-04 - val_loss: 1.0190e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 62/100
# 169/169 - 1s - loss: 1.6699e-04 - val_loss: 8.9501e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 63/100
# 169/169 - 1s - loss: 1.6691e-04 - val_loss: 9.6994e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 64/100
# 169/169 - 1s - loss: 1.8671e-04 - val_loss: 8.5777e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 65/100
# 169/169 - 1s - loss: 1.7171e-04 - val_loss: 2.2084e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 66/100
# 169/169 - 1s - loss: 1.8271e-04 - val_loss: 9.8372e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 67/100
# 169/169 - 1s - loss: 1.8036e-04 - val_loss: 1.4782e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 68/100
# 169/169 - 1s - loss: 1.9424e-04 - val_loss: 1.1897e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 69/100
# 169/169 - 1s - loss: 1.7601e-04 - val_loss: 1.6750e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 70/100
# 169/169 - 1s - loss: 1.6663e-04 - val_loss: 9.8197e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 71/100
# 169/169 - 1s - loss: 1.7720e-04 - val_loss: 1.2084e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 72/100
# 169/169 - 1s - loss: 1.8851e-04 - val_loss: 1.0537e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 73/100
# 169/169 - 1s - loss: 1.7656e-04 - val_loss: 8.9232e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 74/100
# 169/169 - 1s - loss: 1.6730e-04 - val_loss: 1.0043e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 75/100
# 169/169 - 1s - loss: 1.8101e-04 - val_loss: 9.9250e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 76/100
# 169/169 - 1s - loss: 1.6077e-04 - val_loss: 8.7667e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 77/100
# 169/169 - 1s - loss: 1.8058e-04 - val_loss: 8.3913e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 78/100
# 169/169 - 1s - loss: 1.6218e-04 - val_loss: 1.3683e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 79/100
# 169/169 - 1s - loss: 1.7179e-04 - val_loss: 1.0578e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 80/100
# 169/169 - 1s - loss: 1.6858e-04 - val_loss: 1.2159e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 81/100
# 169/169 - 1s - loss: 1.9006e-04 - val_loss: 9.3854e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 82/100
# 169/169 - 1s - loss: 1.5521e-04 - val_loss: 1.0681e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 83/100
# 169/169 - 1s - loss: 1.7390e-04 - val_loss: 1.1196e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 84/100
# 169/169 - 1s - loss: 1.5972e-04 - val_loss: 8.6696e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 85/100
# 169/169 - 1s - loss: 1.8495e-04 - val_loss: 8.8949e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 86/100
# 169/169 - 1s - loss: 1.6095e-04 - val_loss: 1.1823e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 87/100
# 169/169 - 1s - loss: 1.7859e-04 - val_loss: 1.1831e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 88/100
# 169/169 - 1s - loss: 1.8832e-04 - val_loss: 8.4317e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 89/100
# 169/169 - 1s - loss: 1.7062e-04 - val_loss: 1.7577e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 90/100
# 169/169 - 1s - loss: 1.8054e-04 - val_loss: 1.1523e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 91/100
# 169/169 - 1s - loss: 1.7087e-04 - val_loss: 1.2124e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 92/100
# 169/169 - 1s - loss: 1.7745e-04 - val_loss: 8.2957e-05 - lr: 0.0010 - 1s/epoch - 7ms/step
# Epoch 93/100
# 169/169 - 1s - loss: 1.5816e-04 - val_loss: 1.0463e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 94/100
# 169/169 - 1s - loss: 1.6793e-04 - val_loss: 1.2859e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 95/100
# 169/169 - 1s - loss: 1.5761e-04 - val_loss: 8.2716e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 96/100
# 169/169 - 1s - loss: 1.6872e-04 - val_loss: 8.2494e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 97/100
# 169/169 - 1s - loss: 1.7336e-04 - val_loss: 1.2752e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 98/100
# 169/169 - 1s - loss: 1.7243e-04 - val_loss: 9.4701e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 99/100
# 169/169 - 1s - loss: 1.6667e-04 - val_loss: 8.3299e-05 - lr: 0.0010 - 1s/epoch - 8ms/step
# Epoch 100/100
# 169/169 - 1s - loss: 1.8390e-04 - val_loss: 1.0184e-04 - lr: 0.0010 - 1s/epoch - 8ms/step
# 2/2 [==============================] - 3s 8ms/step
# Mean Squared Error (MSE): 2.522415788058802
# Mean Absolute Error (MAE): 0.5565356684822798
# Root Mean Squared Error (RMSE): 1.588211506084376
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 51ms/step
# Dedifferenced forecasted values:
# [3.7386014692485334, 3.7646460950374605, 3.8118696331977846, 3.8445498764514925, 3.8641385555267336, 3.9067437022924425, 3.9547268867492678, 4.008972835540772, 4.05842576622963, 4.107996416091919, 4.159141582250595, 4.210947108268738]

# %% [markdown]
# # With exogenous variables

# %%
# Data Preparation
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data_diff1[['Unemployment Rate (Percent)', 'Civilian Labor Force (Thousands of people)', 'Services Employment Index']])

# Create dataset for Bi-LSTM considering all features
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), :]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY).reshape(-1, 1)

look_back = 10
X, y = create_dataset(data_scaled, look_back)

# Split data into train and test sets
train_size = int(len(X) * 0.8)
trainX, testX = X[:train_size], X[train_size:]
trainY, testY = y[:train_size], y[train_size:]

# Bi-LSTM Model with multiple features
model = Sequential()
model.add(Bidirectional(LSTM(50, input_shape=(look_back, 3))))  # 3 features
model.add(Dense(1))
model.compile(optimizer=Adam(lr=0.01), loss='mean_squared_error')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=0.001)
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)

# Making predictions
predicted_values = model.predict(testX)

# Revert scaling
testY_rescaled = scaler.inverse_transform(np.hstack([testY, np.zeros((len(testY), 2))]))[:, 0]  # Only reverse scale target
predicted_values_rescaled = scaler.inverse_transform(np.hstack([predicted_values, np.zeros((len(predicted_values), 2))]))[:, 0]

# Calculate error metrics
mse = mean_squared_error(testY_rescaled, predicted_values_rescaled)
mae = mean_absolute_error(testY_rescaled, predicted_values_rescaled)
rmse = np.sqrt(mse)

print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'Root Mean Squared Error (RMSE): {rmse}')

# Plotting actual vs predicted values
plt.figure(figsize=(14, 7))
plt.plot(testY_rescaled, label='Actual', color='blue')
plt.plot(predicted_values_rescaled, label='Predicted LSTM with Exogenous', color='orange')
plt.title('Actual vs Predicted Unemployment Rates')
plt.xlabel('Time Index')
plt.ylabel('Unemployment Rate (Percent)')
plt.legend()
plt.show()
# Out:
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# C:\Users\LENOVO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 212/212 - 9s - loss: 0.0017 - 9s/epoch - 42ms/step
# Epoch 2/100
# 212/212 - 1s - loss: 2.1126e-04 - 1s/epoch - 7ms/step
# Epoch 3/100
# 212/212 - 1s - loss: 2.8194e-04 - 1s/epoch - 7ms/step
# Epoch 4/100
# 212/212 - 1s - loss: 2.6371e-04 - 1s/epoch - 7ms/step
# Epoch 5/100
# 212/212 - 1s - loss: 3.5427e-04 - 1s/epoch - 7ms/step
# Epoch 6/100
# 212/212 - 1s - loss: 2.4217e-04 - 1s/epoch - 7ms/step
# Epoch 7/100
# 212/212 - 1s - loss: 3.3153e-04 - 1s/epoch - 7ms/step
# Epoch 8/100
# 212/212 - 1s - loss: 1.8565e-04 - 1s/epoch - 7ms/step
# Epoch 9/100
# 212/212 - 1s - loss: 1.9900e-04 - 1s/epoch - 7ms/step
# Epoch 10/100
# 212/212 - 1s - loss: 2.0258e-04 - 1s/epoch - 7ms/step
# Epoch 11/100
# 212/212 - 1s - loss: 2.0393e-04 - 1s/epoch - 7ms/step
# Epoch 12/100
# 212/212 - 1s - loss: 1.9830e-04 - 1s/epoch - 7ms/step
# Epoch 13/100
# 212/212 - 1s - loss: 1.8796e-04 - 1s/epoch - 7ms/step
# Epoch 14/100
# 212/212 - 1s - loss: 1.8274e-04 - 1s/epoch - 7ms/step
# Epoch 15/100
# 212/212 - 1s - loss: 2.0111e-04 - 1s/epoch - 7ms/step
# Epoch 16/100
# 212/212 - 1s - loss: 2.0534e-04 - 1s/epoch - 7ms/step
# Epoch 17/100
# 212/212 - 1s - loss: 1.7673e-04 - 1s/epoch - 7ms/step
# Epoch 18/100
# 212/212 - 1s - loss: 2.3413e-04 - 1s/epoch - 7ms/step
# Epoch 19/100
# 212/212 - 1s - loss: 1.8576e-04 - 1s/epoch - 7ms/step
# Epoch 20/100
# 212/212 - 1s - loss: 1.6048e-04 - 1s/epoch - 7ms/step
# Epoch 21/100
# 212/212 - 1s - loss: 1.9471e-04 - 1s/epoch - 7ms/step
# Epoch 22/100
# 212/212 - 1s - loss: 1.8965e-04 - 1s/epoch - 7ms/step
# Epoch 23/100
# 212/212 - 1s - loss: 1.7454e-04 - 1s/epoch - 7ms/step
# Epoch 24/100
# 212/212 - 1s - loss: 1.7843e-04 - 1s/epoch - 7ms/step
# Epoch 25/100
# 212/212 - 1s - loss: 1.6316e-04 - 1s/epoch - 7ms/step
# Epoch 26/100
# 212/212 - 1s - loss: 1.7073e-04 - 1s/epoch - 7ms/step
# Epoch 27/100
# 212/212 - 1s - loss: 1.7623e-04 - 1s/epoch - 7ms/step
# Epoch 28/100
# 212/212 - 1s - loss: 1.4910e-04 - 1s/epoch - 7ms/step
# Epoch 29/100
# 212/212 - 1s - loss: 1.9342e-04 - 1s/epoch - 7ms/step
# Epoch 30/100
# 212/212 - 1s - loss: 1.6102e-04 - 1s/epoch - 7ms/step
# Epoch 31/100
# 212/212 - 2s - loss: 1.5773e-04 - 2s/epoch - 7ms/step
# Epoch 32/100
# 212/212 - 1s - loss: 1.6413e-04 - 1s/epoch - 7ms/step
# Epoch 33/100
# 212/212 - 1s - loss: 1.3477e-04 - 1s/epoch - 7ms/step
# Epoch 34/100
# 212/212 - 2s - loss: 1.3038e-04 - 2s/epoch - 7ms/step
# Epoch 35/100
# 212/212 - 2s - loss: 1.6609e-04 - 2s/epoch - 7ms/step
# Epoch 36/100
# 212/212 - 1s - loss: 1.5677e-04 - 1s/epoch - 7ms/step
# Epoch 37/100
# 212/212 - 1s - loss: 1.7075e-04 - 1s/epoch - 7ms/step
# Epoch 38/100
# 212/212 - 1s - loss: 1.3735e-04 - 1s/epoch - 7ms/step
# Epoch 39/100
# 212/212 - 2s - loss: 1.5395e-04 - 2s/epoch - 7ms/step
# Epoch 40/100
# 212/212 - 1s - loss: 1.4499e-04 - 1s/epoch - 7ms/step
# Epoch 41/100
# 212/212 - 1s - loss: 1.4955e-04 - 1s/epoch - 7ms/step
# Epoch 42/100
# 212/212 - 1s - loss: 1.6853e-04 - 1s/epoch - 7ms/step
# Epoch 43/100
# 212/212 - 1s - loss: 1.4942e-04 - 1s/epoch - 7ms/step
# Epoch 44/100
# 212/212 - 2s - loss: 1.4440e-04 - 2s/epoch - 7ms/step
# Epoch 45/100
# 212/212 - 1s - loss: 1.4541e-04 - 1s/epoch - 7ms/step
# Epoch 46/100
# 212/212 - 2s - loss: 1.5155e-04 - 2s/epoch - 7ms/step
# Epoch 47/100
# 212/212 - 2s - loss: 1.5148e-04 - 2s/epoch - 7ms/step
# Epoch 48/100
# 212/212 - 2s - loss: 1.5020e-04 - 2s/epoch - 7ms/step
# Epoch 49/100
# 212/212 - 2s - loss: 1.3562e-04 - 2s/epoch - 7ms/step
# Epoch 50/100
# 212/212 - 2s - loss: 1.3875e-04 - 2s/epoch - 7ms/step
# Epoch 51/100
# 212/212 - 1s - loss: 1.4928e-04 - 1s/epoch - 7ms/step
# Epoch 52/100
# 212/212 - 2s - loss: 1.6038e-04 - 2s/epoch - 7ms/step
# Epoch 53/100
# 212/212 - 2s - loss: 1.2927e-04 - 2s/epoch - 7ms/step
# Epoch 54/100
# 212/212 - 2s - loss: 1.4385e-04 - 2s/epoch - 7ms/step
# Epoch 55/100
# 212/212 - 1s - loss: 1.4895e-04 - 1s/epoch - 7ms/step
# Epoch 56/100
# 212/212 - 2s - loss: 1.2539e-04 - 2s/epoch - 7ms/step
# Epoch 57/100
# 212/212 - 2s - loss: 1.3592e-04 - 2s/epoch - 7ms/step
# Epoch 58/100
# 212/212 - 1s - loss: 1.5157e-04 - 1s/epoch - 7ms/step
# Epoch 59/100
# 212/212 - 1s - loss: 1.3496e-04 - 1s/epoch - 7ms/step
# Epoch 60/100
# 212/212 - 1s - loss: 1.2109e-04 - 1s/epoch - 6ms/step
# Epoch 61/100
# 212/212 - 1s - loss: 1.3705e-04 - 1s/epoch - 6ms/step
# Epoch 62/100
# 212/212 - 1s - loss: 1.2285e-04 - 1s/epoch - 7ms/step
# Epoch 63/100
# 212/212 - 1s - loss: 1.2369e-04 - 1s/epoch - 7ms/step
# Epoch 64/100
# 212/212 - 1s - loss: 1.2853e-04 - 1s/epoch - 7ms/step
# Epoch 65/100
# 212/212 - 1s - loss: 1.3169e-04 - 1s/epoch - 7ms/step
# Epoch 66/100
# 212/212 - 1s - loss: 1.3756e-04 - 1s/epoch - 7ms/step
# Epoch 67/100
# 212/212 - 1s - loss: 1.3132e-04 - 1s/epoch - 7ms/step
# Epoch 68/100
# 212/212 - 2s - loss: 1.2598e-04 - 2s/epoch - 7ms/step
# Epoch 69/100
# 212/212 - 2s - loss: 1.2918e-04 - 2s/epoch - 7ms/step
# Epoch 70/100
# 212/212 - 1s - loss: 1.2487e-04 - 1s/epoch - 7ms/step
# Epoch 71/100
# 212/212 - 1s - loss: 1.3568e-04 - 1s/epoch - 7ms/step
# Epoch 72/100
# 212/212 - 1s - loss: 1.3979e-04 - 1s/epoch - 7ms/step
# Epoch 73/100
# 212/212 - 1s - loss: 1.3017e-04 - 1s/epoch - 7ms/step
# Epoch 74/100
# 212/212 - 2s - loss: 1.2343e-04 - 2s/epoch - 7ms/step
# Epoch 75/100
# 212/212 - 1s - loss: 1.2060e-04 - 1s/epoch - 7ms/step
# Epoch 76/100
# 212/212 - 1s - loss: 1.2485e-04 - 1s/epoch - 7ms/step
# Epoch 77/100
# 212/212 - 1s - loss: 1.2796e-04 - 1s/epoch - 7ms/step
# Epoch 78/100
# 212/212 - 1s - loss: 1.1315e-04 - 1s/epoch - 7ms/step
# Epoch 79/100
# 212/212 - 1s - loss: 1.1634e-04 - 1s/epoch - 7ms/step
# Epoch 80/100
# 212/212 - 1s - loss: 1.2727e-04 - 1s/epoch - 7ms/step
# Epoch 81/100
# 212/212 - 1s - loss: 1.3115e-04 - 1s/epoch - 7ms/step
# Epoch 82/100
# 212/212 - 1s - loss: 1.2063e-04 - 1s/epoch - 7ms/step
# Epoch 83/100
# 212/212 - 1s - loss: 1.3140e-04 - 1s/epoch - 7ms/step
# Epoch 84/100
# 212/212 - 1s - loss: 1.2680e-04 - 1s/epoch - 7ms/step
# Epoch 85/100
# 212/212 - 1s - loss: 1.2395e-04 - 1s/epoch - 7ms/step
# Epoch 86/100
# 212/212 - 1s - loss: 1.2827e-04 - 1s/epoch - 7ms/step
# Epoch 87/100
# 212/212 - 1s - loss: 1.2529e-04 - 1s/epoch - 7ms/step
# Epoch 88/100
# 212/212 - 2s - loss: 1.3841e-04 - 2s/epoch - 7ms/step
# Epoch 89/100
# 212/212 - 2s - loss: 1.2044e-04 - 2s/epoch - 7ms/step
# Epoch 90/100
# 212/212 - 2s - loss: 1.2500e-04 - 2s/epoch - 7ms/step
# Epoch 91/100
# 212/212 - 1s - loss: 1.2666e-04 - 1s/epoch - 7ms/step
# Epoch 92/100
# 212/212 - 2s - loss: 1.2312e-04 - 2s/epoch - 7ms/step
# Epoch 93/100
# 212/212 - 1s - loss: 1.2774e-04 - 1s/epoch - 7ms/step
# Epoch 94/100
# 212/212 - 1s - loss: 1.2445e-04 - 1s/epoch - 7ms/step
# Epoch 95/100
# 212/212 - 1s - loss: 1.1756e-04 - 1s/epoch - 7ms/step
# Epoch 96/100
# 212/212 - 1s - loss: 1.1891e-04 - 1s/epoch - 7ms/step
# Epoch 97/100
# 212/212 - 1s - loss: 1.1991e-04 - 1s/epoch - 7ms/step
# Epoch 98/100
# 212/212 - 1s - loss: 1.2059e-04 - 1s/epoch - 7ms/step
# Epoch 99/100
# 212/212 - 1s - loss: 1.2287e-04 - 1s/epoch - 7ms/step
# Epoch 100/100
# 212/212 - 1s - loss: 1.1789e-04 - 1s/epoch - 7ms/step
# 2/2 [==============================] - 3s 7ms/step
# Mean Squared Error (MSE): 2.550427002713136
# Mean Absolute Error (MAE): 0.5412106169563421
# Root Mean Squared Error (RMSE): 1.5970056364061886

# %%
#!pip uninstall tensorflow
#!pip install tensorflow

# %% [markdown]
# # Part -  2

# %% [markdown]
# # Granger Causality Test

# %%
# Load data (replace 'Data.xlsx' with your data file)
df_data = pd.read_excel('Data.xlsx')

# Define lag order
lag_order = 3

# Exclude the first column from the list of columns
columns_to_test = df_data.columns[2:]

# Generate combinations of column pairs excluding the first column
column_combinations = combinations(columns_to_test, 2)

# Perform Granger causality tests for each column pair
for column_pair in column_combinations:
    # Extract column names for the pair
    col1, col2 = column_pair
    print(f"Granger causality test between '{col1}' and '{col2}':")

    # Extract data for the column pair
    data_pair = df_data[list(column_pair)]

    # Perform Granger causality test
    results = grangercausalitytests(data_pair, maxlag=lag_order, verbose=True)
# Out:
# Granger causality test between 'Unemployment Rate (Percent)' and 'Civilian Labor Force (Thousands of people)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.3947  , p=0.5304  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=0.3990  , p=0.5276  , df=1
# likelihood ratio test: chi2=0.3987  , p=0.5278  , df=1
# parameter F test:         F=0.3947  , p=0.5304  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=7.5753  , p=0.0006  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=15.4312 , p=0.0004  , df=2
# likelihood ratio test: chi2=15.0138 , p=0.0005  , df=2
# parameter F test:         F=7.5753  , p=0.0006  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.5778  , p=0.0038  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=14.0935 , p=0.0028  , df=3
# likelihood ratio test: chi2=13.7430 , p=0.0033  , df=3
# parameter F test:         F=4.5778  , p=0.0038  , df_denom=267, df_num=3
# Granger causality test between 'Unemployment Rate (Percent)' and 'Hires level (Thousands of people)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=24.5196 , p=0.0000  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=24.7890 , p=0.0000  , df=1
# likelihood ratio test: chi2=23.7383 , p=0.0000  , df=1
# parameter F test:         F=24.5196 , p=0.0000  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=14.0835 , p=0.0000  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=28.6886 , p=0.0000  , df=2
# likelihood ratio test: chi2=27.2887 , p=0.0000  , df=2
# parameter F test:         F=14.0835 , p=0.0000  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=10.2522 , p=0.0000  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=31.5629 , p=0.0000  , df=3
# likelihood ratio test: chi2=29.8736 , p=0.0000  , df=3
# parameter F test:         F=10.2522 , p=0.0000  , df_denom=267, df_num=3
# Granger causality test between 'Unemployment Rate (Percent)' and 'Separations level (Thousands of people)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=152.7268, p=0.0000  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=154.4052, p=0.0000  , df=1
# likelihood ratio test: chi2=122.6340, p=0.0000  , df=1
# parameter F test:         F=152.7268, p=0.0000  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=519.2014, p=0.0000  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=1057.6326, p=0.0000  , df=2
# likelihood ratio test: chi2=433.9886, p=0.0000  , df=2
# parameter F test:         F=519.2014, p=0.0000  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=693.3914, p=0.0000  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=2134.7106, p=0.0000  , df=3
# likelihood ratio test: chi2=595.5989, p=0.0000  , df=3
# parameter F test:         F=693.3914, p=0.0000  , df_denom=267, df_num=3
# Granger causality test between 'Unemployment Rate (Percent)' and 'Disposable Personal Income SAAR (Billions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.3634  , p=0.1254  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=2.3893  , p=0.1222  , df=1
# likelihood ratio test: chi2=2.3790  , p=0.1230  , df=1
# parameter F test:         F=2.3634  , p=0.1254  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.7090  , p=0.1830  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=3.4812  , p=0.1754  , df=2
# likelihood ratio test: chi2=3.4594  , p=0.1773  , df=2
# parameter F test:         F=1.7090  , p=0.1830  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.8033  , p=0.1469  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=5.5516  , p=0.1356  , df=3
# likelihood ratio test: chi2=5.4961  , p=0.1389  , df=3
# parameter F test:         F=1.8033  , p=0.1469  , df_denom=267, df_num=3
# Granger causality test between 'Unemployment Rate (Percent)' and 'Personal Consumption Expenditures SAAR (Billions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.2850  , p=0.1318  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=2.3101  , p=0.1285  , df=1
# likelihood ratio test: chi2=2.3005  , p=0.1293  , df=1
# parameter F test:         F=2.2850  , p=0.1318  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=92.7913 , p=0.0000  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=189.0192, p=0.0000  , df=2
# likelihood ratio test: chi2=143.8676, p=0.0000  , df=2
# parameter F test:         F=92.7913 , p=0.0000  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=64.7642 , p=0.0000  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=199.3865, p=0.0000  , df=3
# likelihood ratio test: chi2=149.8188, p=0.0000  , df=3
# parameter F test:         F=64.7642 , p=0.0000  , df_denom=267, df_num=3
# Granger causality test between 'Unemployment Rate (Percent)' and 'Personal Savings SAAR (Billions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.4105  , p=0.2360  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=1.4260  , p=0.2324  , df=1
# likelihood ratio test: chi2=1.4223  , p=0.2330  , df=1
# parameter F test:         F=1.4105  , p=0.2360  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.4304  , p=0.0338  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=6.9879  , p=0.0304  , df=2
# likelihood ratio test: chi2=6.9006  , p=0.0317  , df=2
# parameter F test:         F=3.4304  , p=0.0338  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.0643  , p=0.1053  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=6.3553  , p=0.0955  , df=3
# likelihood ratio test: chi2=6.2827  , p=0.0986  , df=3
# parameter F test:         F=2.0643  , p=0.1053  , df_denom=267, df_num=3
# Granger causality test between 'Unemployment Rate (Percent)' and 'Manufacturing PMI':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.9801  , p=0.0265  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=5.0348  , p=0.0248  , df=1
# likelihood ratio test: chi2=4.9894  , p=0.0255  , df=1
# parameter F test:         F=4.9801  , p=0.0265  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.1277  , p=0.1211  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=4.3342  , p=0.1145  , df=2
# likelihood ratio test: chi2=4.3004  , p=0.1165  , df=2
# parameter F test:         F=2.1277  , p=0.1211  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.3588  , p=0.0720  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=7.2620  , p=0.0640  , df=3
# likelihood ratio test: chi2=7.1675  , p=0.0667  , df=3
# parameter F test:         F=2.3588  , p=0.0720  , df_denom=267, df_num=3
# Granger causality test between 'Unemployment Rate (Percent)' and 'Manufacturing Employment Index':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=2.6495  , p=0.1047  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=2.6786  , p=0.1017  , df=1
# likelihood ratio test: chi2=2.6657  , p=0.1025  , df=1
# parameter F test:         F=2.6495  , p=0.1047  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.2164  , p=0.2979  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=2.4778  , p=0.2897  , df=2
# likelihood ratio test: chi2=2.4667  , p=0.2913  , df=2
# parameter F test:         F=1.2164  , p=0.2979  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3627  , p=0.2545  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=4.1954  , p=0.2411  , df=3
# likelihood ratio test: chi2=4.1636  , p=0.2443  , df=3
# parameter F test:         F=1.3627  , p=0.2545  , df_denom=267, df_num=3
# Granger causality test between 'Unemployment Rate (Percent)' and 'Services Employment Index':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.0599  , p=0.0449  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=4.1046  , p=0.0428  , df=1
# likelihood ratio test: chi2=4.0743  , p=0.0435  , df=1
# parameter F test:         F=4.0599  , p=0.0449  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.4475  , p=0.0332  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=7.0227  , p=0.0299  , df=2
# likelihood ratio test: chi2=6.9345  , p=0.0312  , df=2
# parameter F test:         F=3.4475  , p=0.0332  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.9164  , p=0.0347  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=8.9787  , p=0.0296  , df=3
# likelihood ratio test: chi2=8.8347  , p=0.0316  , df=3
# parameter F test:         F=2.9164  , p=0.0347  , df_denom=267, df_num=3
# Granger causality test between 'Unemployment Rate (Percent)' and 'Advance Monthly Sales for retail & food services (Millions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.2687  , p=0.0398  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=4.3157  , p=0.0378  , df=1
# likelihood ratio test: chi2=4.2823  , p=0.0385  , df=1
# parameter F test:         F=4.2687  , p=0.0398  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=30.8895 , p=0.0000  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=62.9231 , p=0.0000  , df=2
# likelihood ratio test: chi2=56.6630 , p=0.0000  , df=2
# parameter F test:         F=30.8895 , p=0.0000  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=21.0734 , p=0.0000  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=64.8777 , p=0.0000  , df=3
# likelihood ratio test: chi2=58.2281 , p=0.0000  , df=3
# parameter F test:         F=21.0734 , p=0.0000  , df_denom=267, df_num=3
# Granger causality test between 'Unemployment Rate (Percent)' and 'CPI':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.4189  , p=0.2346  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=1.4345  , p=0.2310  , df=1
# likelihood ratio test: chi2=1.4308  , p=0.2316  , df=1
# parameter F test:         F=1.4189  , p=0.2346  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.8417  , p=0.1605  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=3.7517  , p=0.1532  , df=2
# likelihood ratio test: chi2=3.7263  , p=0.1552  , df=2
# parameter F test:         F=1.8417  , p=0.1605  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# ssr based F test:         F=1.4179  , p=0.2379  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=4.3653  , p=0.2246  , df=3
# likelihood ratio test: chi2=4.3309  , p=0.2279  , df=3
# parameter F test:         F=1.4179  , p=0.2379  , df_denom=267, df_num=3
# Granger causality test between 'Civilian Labor Force (Thousands of people)' and 'Hires level (Thousands of people)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=8.4521  , p=0.0039  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=8.5450  , p=0.0035  , df=1
# likelihood ratio test: chi2=8.4154  , p=0.0037  , df=1
# parameter F test:         F=8.4521  , p=0.0039  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=12.1309 , p=0.0000  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=24.7111 , p=0.0000  , df=2
# likelihood ratio test: chi2=23.6632 , p=0.0000  , df=2
# parameter F test:         F=12.1309 , p=0.0000  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=6.1362  , p=0.0005  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=18.8912 , p=0.0003  , df=3
# likelihood ratio test: chi2=18.2684 , p=0.0004  , df=3
# parameter F test:         F=6.1362  , p=0.0005  , df_denom=267, df_num=3
# Granger causality test between 'Civilian Labor Force (Thousands of people)' and 'Separations level (Thousands of people)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=52.1247 , p=0.0000  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=52.6975 , p=0.0000  , df=1
# likelihood ratio test: chi2=48.2274 , p=0.0000  , df=1
# parameter F test:         F=52.1247 , p=0.0000  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=141.6710, p=0.0000  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=288.5891, p=0.0000  , df=2
# likelihood ratio test: chi2=197.3275, p=0.0000  , df=2
# parameter F test:         F=141.6710, p=0.0000  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=97.4043 , p=0.0000  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=299.8738, p=0.0000  , df=3
# likelihood ratio test: chi2=202.5631, p=0.0000  , df=3
# parameter F test:         F=97.4043 , p=0.0000  , df_denom=267, df_num=3
# Granger causality test between 'Civilian Labor Force (Thousands of people)' and 'Disposable Personal Income SAAR (Billions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=12.8009 , p=0.0004  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=12.9416 , p=0.0003  , df=1
# likelihood ratio test: chi2=12.6473 , p=0.0004  , df=1
# parameter F test:         F=12.8009 , p=0.0004  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=7.4064  , p=0.0007  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=15.0871 , p=0.0005  , df=2
# likelihood ratio test: chi2=14.6878 , p=0.0006  , df=2
# parameter F test:         F=7.4064  , p=0.0007  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.6122  , p=0.0036  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=14.1994 , p=0.0026  , df=3
# likelihood ratio test: chi2=13.8437 , p=0.0031  , df=3
# parameter F test:         F=4.6122  , p=0.0036  , df_denom=267, df_num=3
# Granger causality test between 'Civilian Labor Force (Thousands of people)' and 'Personal Consumption Expenditures SAAR (Billions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=11.4582 , p=0.0008  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=11.5841 , p=0.0007  , df=1
# likelihood ratio test: chi2=11.3476 , p=0.0008  , df=1
# parameter F test:         F=11.4582 , p=0.0008  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=29.0003 , p=0.0000  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=59.0747 , p=0.0000  , df=2
# likelihood ratio test: chi2=53.5132 , p=0.0000  , df=2
# parameter F test:         F=29.0003 , p=0.0000  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=20.5898 , p=0.0000  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=63.3889 , p=0.0000  , df=3
# likelihood ratio test: chi2=57.0216 , p=0.0000  , df=3
# parameter F test:         F=20.5898 , p=0.0000  , df_denom=267, df_num=3
# Granger causality test between 'Civilian Labor Force (Thousands of people)' and 'Personal Savings SAAR (Billions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.1964  , p=0.0749  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=3.2315  , p=0.0722  , df=1
# likelihood ratio test: chi2=3.2127  , p=0.0731  , df=1
# parameter F test:         F=3.1964  , p=0.0749  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.7626  , p=0.1736  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=3.5906  , p=0.1661  , df=2
# likelihood ratio test: chi2=3.5673  , p=0.1680  , df=2
# parameter F test:         F=1.7626  , p=0.1736  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5595  , p=0.6422  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=1.7225  , p=0.6320  , df=3
# likelihood ratio test: chi2=1.7171  , p=0.6331  , df=3
# parameter F test:         F=0.5595  , p=0.6422  , df_denom=267, df_num=3
# Granger causality test between 'Civilian Labor Force (Thousands of people)' and 'Manufacturing PMI':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0232  , p=0.8790  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=0.0235  , p=0.8783  , df=1
# likelihood ratio test: chi2=0.0235  , p=0.8783  , df=1
# parameter F test:         F=0.0232  , p=0.8790  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0970  , p=0.9075  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=0.1977  , p=0.9059  , df=2
# likelihood ratio test: chi2=0.1976  , p=0.9059  , df=2
# parameter F test:         F=0.0970  , p=0.9075  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4728  , p=0.2223  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=4.5342  , p=0.2093  , df=3
# likelihood ratio test: chi2=4.4971  , p=0.2126  , df=3
# parameter F test:         F=1.4728  , p=0.2223  , df_denom=267, df_num=3
# Granger causality test between 'Civilian Labor Force (Thousands of people)' and 'Manufacturing Employment Index':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0035  , p=0.9527  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=0.0036  , p=0.9524  , df=1
# likelihood ratio test: chi2=0.0036  , p=0.9524  , df=1
# parameter F test:         F=0.0035  , p=0.9527  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0106  , p=0.9894  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=0.0216  , p=0.9892  , df=2
# likelihood ratio test: chi2=0.0216  , p=0.9892  , df=2
# parameter F test:         F=0.0106  , p=0.9894  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.3066  , p=0.2726  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=4.0224  , p=0.2591  , df=3
# likelihood ratio test: chi2=3.9932  , p=0.2622  , df=3
# parameter F test:         F=1.3066  , p=0.2726  , df_denom=267, df_num=3
# Granger causality test between 'Civilian Labor Force (Thousands of people)' and 'Services Employment Index':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0099  , p=0.9208  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=0.0100  , p=0.9203  , df=1
# likelihood ratio test: chi2=0.0100  , p=0.9203  , df=1
# parameter F test:         F=0.0099  , p=0.9208  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.4817  , p=0.6183  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=0.9813  , p=0.6122  , df=2
# likelihood ratio test: chi2=0.9795  , p=0.6128  , df=2
# parameter F test:         F=0.4817  , p=0.6183  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.5111  , p=0.6750  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=1.5734  , p=0.6654  , df=3
# likelihood ratio test: chi2=1.5689  , p=0.6665  , df=3
# parameter F test:         F=0.5111  , p=0.6750  , df_denom=267, df_num=3
# Granger causality test between 'Civilian Labor Force (Thousands of people)' and 'Advance Monthly Sales for retail & food services (Millions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=9.9709  , p=0.0018  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=10.0805 , p=0.0015  , df=1
# likelihood ratio test: chi2=9.9007  , p=0.0017  , df=1
# parameter F test:         F=9.9709  , p=0.0018  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=17.3910 , p=0.0000  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=35.4262 , p=0.0000  , df=2
# likelihood ratio test: chi2=33.3231 , p=0.0000  , df=2
# parameter F test:         F=17.3910 , p=0.0000  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=10.5664 , p=0.0000  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=32.5302 , p=0.0000  , df=3
# likelihood ratio test: chi2=30.7396 , p=0.0000  , df=3
# parameter F test:         F=10.5664 , p=0.0000  , df_denom=267, df_num=3
# Granger causality test between 'Civilian Labor Force (Thousands of people)' and 'CPI':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=10.2010 , p=0.0016  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=10.3131 , p=0.0013  , df=1
# likelihood ratio test: chi2=10.1251 , p=0.0015  , df=1
# parameter F test:         F=10.2010 , p=0.0016  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.9869  , p=0.0075  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=10.1584 , p=0.0062  , df=2
# likelihood ratio test: chi2=9.9753  , p=0.0068  , df=2
# parameter F test:         F=4.9869  , p=0.0075  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.1096  , p=0.0269  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=9.5735  , p=0.0226  , df=3
# likelihood ratio test: chi2=9.4101  , p=0.0243  , df=3
# parameter F test:         F=3.1096  , p=0.0269  , df_denom=267, df_num=3
# Granger causality test between 'Hires level (Thousands of people)' and 'Separations level (Thousands of people)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=15.7126 , p=0.0001  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=15.8852 , p=0.0001  , df=1
# likelihood ratio test: chi2=15.4449 , p=0.0001  , df=1
# parameter F test:         F=15.7126 , p=0.0001  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=214.6531, p=0.0000  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=437.2563, p=0.0000  , df=2
# likelihood ratio test: chi2=261.7083, p=0.0000  , df=2
# parameter F test:         F=214.6531, p=0.0000  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=164.6891, p=0.0000  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=507.0205, p=0.0000  , df=3
# likelihood ratio test: chi2=287.0077, p=0.0000  , df=3
# parameter F test:         F=164.6891, p=0.0000  , df_denom=267, df_num=3
# Granger causality test between 'Hires level (Thousands of people)' and 'Disposable Personal Income SAAR (Billions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=14.0918 , p=0.0002  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=14.2467 , p=0.0002  , df=1
# likelihood ratio test: chi2=13.8912 , p=0.0002  , df=1
# parameter F test:         F=14.0918 , p=0.0002  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=15.1046 , p=0.0000  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=30.7686 , p=0.0000  , df=2
# likelihood ratio test: chi2=29.1658 , p=0.0000  , df=2
# parameter F test:         F=15.1046 , p=0.0000  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=10.1313 , p=0.0000  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=31.1908 , p=0.0000  , df=3
# likelihood ratio test: chi2=29.5397 , p=0.0000  , df=3
# parameter F test:         F=10.1313 , p=0.0000  , df_denom=267, df_num=3
# Granger causality test between 'Hires level (Thousands of people)' and 'Personal Consumption Expenditures SAAR (Billions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.7111  , p=0.0101  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=6.7849  , p=0.0092  , df=1
# likelihood ratio test: chi2=6.7028  , p=0.0096  , df=1
# parameter F test:         F=6.7111  , p=0.0101  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=28.2762 , p=0.0000  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=57.5997 , p=0.0000  , df=2
# likelihood ratio test: chi2=52.2964 , p=0.0000  , df=2
# parameter F test:         F=28.2762 , p=0.0000  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=39.6816 , p=0.0000  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=122.1659, p=0.0000  , df=3
# likelihood ratio test: chi2=101.0252, p=0.0000  , df=3
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# parameter F test:         F=39.6816 , p=0.0000  , df_denom=267, df_num=3
# Granger causality test between 'Hires level (Thousands of people)' and 'Personal Savings SAAR (Billions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=38.8549 , p=0.0000  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=39.2819 , p=0.0000  , df=1
# likelihood ratio test: chi2=36.7263 , p=0.0000  , df=1
# parameter F test:         F=38.8549 , p=0.0000  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=33.9499 , p=0.0000  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=69.1571 , p=0.0000  , df=2
# likelihood ratio test: chi2=61.6900 , p=0.0000  , df=2
# parameter F test:         F=33.9499 , p=0.0000  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=26.8377 , p=0.0000  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=82.6238 , p=0.0000  , df=3
# likelihood ratio test: chi2=72.2136 , p=0.0000  , df=3
# parameter F test:         F=26.8377 , p=0.0000  , df_denom=267, df_num=3
# Granger causality test between 'Hires level (Thousands of people)' and 'Manufacturing PMI':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5149  , p=0.4736  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=0.5206  , p=0.4706  , df=1
# likelihood ratio test: chi2=0.5201  , p=0.4708  , df=1
# parameter F test:         F=0.5149  , p=0.4736  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=7.6291  , p=0.0006  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=15.5408 , p=0.0004  , df=2
# likelihood ratio test: chi2=15.1176 , p=0.0005  , df=2
# parameter F test:         F=7.6291  , p=0.0006  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.5401  , p=0.0040  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=13.9774 , p=0.0029  , df=3
# likelihood ratio test: chi2=13.6326 , p=0.0035  , df=3
# parameter F test:         F=4.5401  , p=0.0040  , df_denom=267, df_num=3
# Granger causality test between 'Hires level (Thousands of people)' and 'Manufacturing Employment Index':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4191  , p=0.5179  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=0.4237  , p=0.5151  , df=1
# likelihood ratio test: chi2=0.4234  , p=0.5152  , df=1
# parameter F test:         F=0.4191  , p=0.5179  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=9.4688  , p=0.0001  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=19.2883 , p=0.0001  , df=2
# likelihood ratio test: chi2=18.6420 , p=0.0001  , df=2
# parameter F test:         F=9.4688  , p=0.0001  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=7.9746  , p=0.0000  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=24.5510 , p=0.0000  , df=3
# likelihood ratio test: chi2=23.5127 , p=0.0000  , df=3
# parameter F test:         F=7.9746  , p=0.0000  , df_denom=267, df_num=3
# Granger causality test between 'Hires level (Thousands of people)' and 'Services Employment Index':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1764  , p=0.6748  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=0.1783  , p=0.6728  , df=1
# likelihood ratio test: chi2=0.1783  , p=0.6729  , df=1
# parameter F test:         F=0.1764  , p=0.6748  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=11.9325 , p=0.0000  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=24.3069 , p=0.0000  , df=2
# likelihood ratio test: chi2=23.2920 , p=0.0000  , df=2
# parameter F test:         F=11.9325 , p=0.0000  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=13.2582 , p=0.0000  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=40.8173 , p=0.0000  , df=3
# likelihood ratio test: chi2=38.0489 , p=0.0000  , df=3
# parameter F test:         F=13.2582 , p=0.0000  , df_denom=267, df_num=3
# Granger causality test between 'Hires level (Thousands of people)' and 'Advance Monthly Sales for retail & food services (Millions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=7.6872  , p=0.0059  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=7.7717  , p=0.0053  , df=1
# likelihood ratio test: chi2=7.6643  , p=0.0056  , df=1
# parameter F test:         F=7.6872  , p=0.0059  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=12.0211 , p=0.0000  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=24.4874 , p=0.0000  , df=2
# likelihood ratio test: chi2=23.4578 , p=0.0000  , df=2
# parameter F test:         F=12.0211 , p=0.0000  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=20.3434 , p=0.0000  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=62.6303 , p=0.0000  , df=3
# likelihood ratio test: chi2=56.4049 , p=0.0000  , df=3
# parameter F test:         F=20.3434 , p=0.0000  , df_denom=267, df_num=3
# Granger causality test between 'Hires level (Thousands of people)' and 'CPI':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.6650  , p=0.0104  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=6.7382  , p=0.0094  , df=1
# likelihood ratio test: chi2=6.6573  , p=0.0099  , df=1
# parameter F test:         F=6.6650  , p=0.0104  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.9844  , p=0.0522  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=6.0794  , p=0.0478  , df=2
# likelihood ratio test: chi2=6.0132  , p=0.0495  , df=2
# parameter F test:         F=2.9844  , p=0.0522  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0437  , p=0.3737  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=3.2132  , p=0.3599  , df=3
# likelihood ratio test: chi2=3.1945  , p=0.3626  , df=3
# parameter F test:         F=1.0437  , p=0.3737  , df_denom=267, df_num=3
# Granger causality test between 'Separations level (Thousands of people)' and 'Disposable Personal Income SAAR (Billions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=9.9955  , p=0.0017  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=10.1053 , p=0.0015  , df=1
# likelihood ratio test: chi2=9.9247  , p=0.0016  , df=1
# parameter F test:         F=9.9955  , p=0.0017  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=7.5702  , p=0.0006  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=15.4208 , p=0.0004  , df=2
# likelihood ratio test: chi2=15.0039 , p=0.0006  , df=2
# parameter F test:         F=7.5702  , p=0.0006  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.4876  , p=0.0609  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=7.6585  , p=0.0536  , df=3
# likelihood ratio test: chi2=7.5534  , p=0.0562  , df=3
# parameter F test:         F=2.4876  , p=0.0609  , df_denom=267, df_num=3
# Granger causality test between 'Separations level (Thousands of people)' and 'Personal Consumption Expenditures SAAR (Billions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=13.6626 , p=0.0003  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=13.8127 , p=0.0002  , df=1
# likelihood ratio test: chi2=13.4782 , p=0.0002  , df=1
# parameter F test:         F=13.6626 , p=0.0003  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=17.0901 , p=0.0000  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=34.8132 , p=0.0000  , df=2
# likelihood ratio test: chi2=32.7796 , p=0.0000  , df=2
# parameter F test:         F=17.0901 , p=0.0000  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.4785  , p=0.0044  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=13.7879 , p=0.0032  , df=3
# likelihood ratio test: chi2=13.4522 , p=0.0038  , df=3
# parameter F test:         F=4.4785  , p=0.0044  , df_denom=267, df_num=3
# Granger causality test between 'Separations level (Thousands of people)' and 'Personal Savings SAAR (Billions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.9087  , p=0.3413  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=0.9187  , p=0.3378  , df=1
# likelihood ratio test: chi2=0.9172  , p=0.3382  , df=1
# parameter F test:         F=0.9087  , p=0.3413  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.2946  , p=0.0146  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=8.7483  , p=0.0126  , df=2
# likelihood ratio test: chi2=8.6121  , p=0.0135  , df=2
# parameter F test:         F=4.2946  , p=0.0146  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8832  , p=0.4503  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=2.7191  , p=0.4370  , df=3
# likelihood ratio test: chi2=2.7057  , p=0.4393  , df=3
# parameter F test:         F=0.8832  , p=0.4503  , df_denom=267, df_num=3
# Granger causality test between 'Separations level (Thousands of people)' and 'Manufacturing PMI':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4015  , p=0.5268  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=0.4059  , p=0.5241  , df=1
# likelihood ratio test: chi2=0.4056  , p=0.5242  , df=1
# parameter F test:         F=0.4015  , p=0.5268  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.2261  , p=0.7978  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=0.4606  , p=0.7943  , df=2
# likelihood ratio test: chi2=0.4603  , p=0.7944  , df=2
# parameter F test:         F=0.2261  , p=0.7978  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9770  , p=0.4040  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=3.0080  , p=0.3904  , df=3
# likelihood ratio test: chi2=2.9916  , p=0.3929  , df=3
# parameter F test:         F=0.9770  , p=0.4040  , df_denom=267, df_num=3
# Granger causality test between 'Separations level (Thousands of people)' and 'Manufacturing Employment Index':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2902  , p=0.5905  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=0.2934  , p=0.5880  , df=1
# likelihood ratio test: chi2=0.2933  , p=0.5881  , df=1
# parameter F test:         F=0.2902  , p=0.5905  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5761  , p=0.2087  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=3.2106  , p=0.2008  , df=2
# likelihood ratio test: chi2=3.1920  , p=0.2027  , df=2
# parameter F test:         F=1.5761  , p=0.2087  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4297  , p=0.7319  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=1.3228  , p=0.7237  , df=3
# likelihood ratio test: chi2=1.3196  , p=0.7245  , df=3
# parameter F test:         F=0.4297  , p=0.7319  , df_denom=267, df_num=3
# Granger causality test between 'Separations level (Thousands of people)' and 'Services Employment Index':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=11.4947 , p=0.0008  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=11.6210 , p=0.0007  , df=1
# likelihood ratio test: chi2=11.3830 , p=0.0007  , df=1
# parameter F test:         F=11.4947 , p=0.0008  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=7.1652  , p=0.0009  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=14.5958 , p=0.0007  , df=2
# likelihood ratio test: chi2=14.2217 , p=0.0008  , df=2
# parameter F test:         F=7.1652  , p=0.0009  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.2546  , p=0.0059  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=13.0986 , p=0.0044  , df=3
# likelihood ratio test: chi2=12.7951 , p=0.0051  , df=3
# parameter F test:         F=4.2546  , p=0.0059  , df_denom=267, df_num=3
# Granger causality test between 'Separations level (Thousands of people)' and 'Advance Monthly Sales for retail & food services (Millions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=16.2671 , p=0.0001  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=16.4458 , p=0.0001  , df=1
# likelihood ratio test: chi2=15.9745 , p=0.0001  , df=1
# parameter F test:         F=16.2671 , p=0.0001  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=13.4766 , p=0.0000  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=27.4524 , p=0.0000  , df=2
# likelihood ratio test: chi2=26.1670 , p=0.0000  , df=2
# parameter F test:         F=13.4766 , p=0.0000  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.8640  , p=0.0099  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=11.8959 , p=0.0077  , df=3
# likelihood ratio test: chi2=11.6449 , p=0.0087  , df=3
# parameter F test:         F=3.8640  , p=0.0099  , df_denom=267, df_num=3
# Granger causality test between 'Separations level (Thousands of people)' and 'CPI':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=8.0867  , p=0.0048  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=8.1756  , p=0.0042  , df=1
# likelihood ratio test: chi2=8.0568  , p=0.0045  , df=1
# parameter F test:         F=8.0867  , p=0.0048  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=6.2582  , p=0.0022  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=12.7481 , p=0.0017  , df=2
# likelihood ratio test: chi2=12.4615 , p=0.0020  , df=2
# parameter F test:         F=6.2582  , p=0.0022  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.7052  , p=0.0458  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=8.3284  , p=0.0397  , df=3
# likelihood ratio test: chi2=8.2043  , p=0.0420  , df=3
# parameter F test:         F=2.7052  , p=0.0458  , df_denom=267, df_num=3
# Granger causality test between 'Disposable Personal Income SAAR (Billions of Dollars)' and 'Personal Consumption Expenditures SAAR (Billions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=25.5679 , p=0.0000  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=25.8489 , p=0.0000  , df=1
# likelihood ratio test: chi2=24.7091 , p=0.0000  , df=1
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# parameter F test:         F=25.5679 , p=0.0000  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=20.3832 , p=0.0000  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=41.5214 , p=0.0000  , df=2
# likelihood ratio test: chi2=38.6704 , p=0.0000  , df=2
# parameter F test:         F=20.3832 , p=0.0000  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=13.2238 , p=0.0000  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=40.7116 , p=0.0000  , df=3
# likelihood ratio test: chi2=37.9568 , p=0.0000  , df=3
# parameter F test:         F=13.2238 , p=0.0000  , df_denom=267, df_num=3
# Granger causality test between 'Disposable Personal Income SAAR (Billions of Dollars)' and 'Personal Savings SAAR (Billions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=24.9757 , p=0.0000  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=25.2501 , p=0.0000  , df=1
# likelihood ratio test: chi2=24.1610 , p=0.0000  , df=1
# parameter F test:         F=24.9757 , p=0.0000  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=20.5699 , p=0.0000  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=41.9017 , p=0.0000  , df=2
# likelihood ratio test: chi2=39.0006 , p=0.0000  , df=2
# parameter F test:         F=20.5699 , p=0.0000  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=13.2761 , p=0.0000  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=40.8726 , p=0.0000  , df=3
# likelihood ratio test: chi2=38.0970 , p=0.0000  , df=3
# parameter F test:         F=13.2761 , p=0.0000  , df_denom=267, df_num=3
# Granger causality test between 'Disposable Personal Income SAAR (Billions of Dollars)' and 'Manufacturing PMI':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0231  , p=0.8793  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=0.0233  , p=0.8786  , df=1
# ...
# likelihood ratio test: chi2=0.8771  , p=0.6450  , df=2
# parameter F test:         F=0.4313  , p=0.6501  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3579  , p=0.7834  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=1.1019  , p=0.7766  , df=3
# likelihood ratio test: chi2=1.0997  , p=0.7771  , df=3
# parameter F test:         F=0.3579  , p=0.7834  , df_denom=267, df_num=3
# Granger causality test between 'Personal Savings SAAR (Billions of Dollars)' and 'Services Employment Index':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0201  , p=0.8873  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=0.0203  , p=0.8866  , df=1
# likelihood ratio test: chi2=0.0203  , p=0.8866  , df=1
# parameter F test:         F=0.0201  , p=0.8873  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=6.1481  , p=0.0024  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=12.5240 , p=0.0019  , df=2
# likelihood ratio test: chi2=12.2472 , p=0.0022  , df=2
# parameter F test:         F=6.1481  , p=0.0024  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.4247  , p=0.0047  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=13.6220 , p=0.0035  , df=3
# likelihood ratio test: chi2=13.2942 , p=0.0040  , df=3
# parameter F test:         F=4.4247  , p=0.0047  , df_denom=267, df_num=3
# Granger causality test between 'Personal Savings SAAR (Billions of Dollars)' and 'Advance Monthly Sales for retail & food services (Millions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=4.9431  , p=0.0270  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=4.9974  , p=0.0254  , df=1
# likelihood ratio test: chi2=4.9527  , p=0.0261  , df=1
# parameter F test:         F=4.9431  , p=0.0270  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=42.6775 , p=0.0000  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=86.9356 , p=0.0000  , df=2
# likelihood ratio test: chi2=75.5412 , p=0.0000  , df=2
# parameter F test:         F=42.6775 , p=0.0000  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=29.2125 , p=0.0000  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=89.9350 , p=0.0000  , df=3
# likelihood ratio test: chi2=77.7741 , p=0.0000  , df=3
# parameter F test:         F=29.2125 , p=0.0000  , df_denom=267, df_num=3
# Granger causality test between 'Personal Savings SAAR (Billions of Dollars)' and 'CPI':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=8.0904  , p=0.0048  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=8.1793  , p=0.0042  , df=1
# likelihood ratio test: chi2=8.0605  , p=0.0045  , df=1
# parameter F test:         F=8.0904  , p=0.0048  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.9321  , p=0.0207  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=8.0099  , p=0.0182  , df=2
# likelihood ratio test: chi2=7.8954  , p=0.0193  , df=2
# parameter F test:         F=3.9321  , p=0.0207  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.7407  , p=0.0437  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=8.4377  , p=0.0378  , df=3
# likelihood ratio test: chi2=8.3103  , p=0.0400  , df=3
# parameter F test:         F=2.7407  , p=0.0437  , df_denom=267, df_num=3
# Granger causality test between 'Manufacturing PMI' and 'Manufacturing Employment Index':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=7.3733  , p=0.0070  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=7.4543  , p=0.0063  , df=1
# likelihood ratio test: chi2=7.3554  , p=0.0067  , df=1
# parameter F test:         F=7.3733  , p=0.0070  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=8.4210  , p=0.0003  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=17.1539 , p=0.0002  , df=2
# likelihood ratio test: chi2=16.6401 , p=0.0002  , df=2
# parameter F test:         F=8.4210  , p=0.0003  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.3850  , p=0.0013  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=16.5786 , p=0.0009  , df=3
# likelihood ratio test: chi2=16.0964 , p=0.0011  , df=3
# parameter F test:         F=5.3850  , p=0.0013  , df_denom=267, df_num=3
# Granger causality test between 'Manufacturing PMI' and 'Services Employment Index':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.1279  , p=0.2892  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=1.1403  , p=0.2856  , df=1
# likelihood ratio test: chi2=1.1380  , p=0.2861  , df=1
# parameter F test:         F=1.1279  , p=0.2892  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=8.2118  , p=0.0003  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=16.7278 , p=0.0002  , df=2
# likelihood ratio test: chi2=16.2388 , p=0.0003  , df=2
# parameter F test:         F=8.2118  , p=0.0003  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.0589  , p=0.0020  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=15.5746 , p=0.0014  , df=3
# likelihood ratio test: chi2=15.1481 , p=0.0017  , df=3
# parameter F test:         F=5.0589  , p=0.0020  , df_denom=267, df_num=3
# Granger causality test between 'Manufacturing PMI' and 'Advance Monthly Sales for retail & food services (Millions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6238  , p=0.4303  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=0.6306  , p=0.4271  , df=1
# likelihood ratio test: chi2=0.6299  , p=0.4274  , df=1
# parameter F test:         F=0.6238  , p=0.4303  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=7.9417  , p=0.0004  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=16.1775 , p=0.0003  , df=2
# likelihood ratio test: chi2=15.7195 , p=0.0004  , df=2
# parameter F test:         F=7.9417  , p=0.0004  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.5147  , p=0.0011  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=16.9777 , p=0.0007  , df=3
# likelihood ratio test: chi2=16.4725 , p=0.0009  , df=3
# parameter F test:         F=5.5147  , p=0.0011  , df_denom=267, df_num=3
# Granger causality test between 'Manufacturing PMI' and 'CPI':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4328  , p=0.5112  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=0.4376  , p=0.5083  , df=1
# likelihood ratio test: chi2=0.4372  , p=0.5085  , df=1
# parameter F test:         F=0.4328  , p=0.5112  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.9939  , p=0.3715  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=2.0246  , p=0.3634  , df=2
# likelihood ratio test: chi2=2.0172  , p=0.3647  , df=2
# parameter F test:         F=0.9939  , p=0.3715  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.6441  , p=0.1795  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=5.0616  , p=0.1673  , df=3
# likelihood ratio test: chi2=5.0154  , p=0.1707  , df=3
# parameter F test:         F=1.6441  , p=0.1795  , df_denom=267, df_num=3
# Granger causality test between 'Manufacturing Employment Index' and 'Services Employment Index':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0416  , p=0.8386  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=0.0420  , p=0.8375  , df=1
# likelihood ratio test: chi2=0.0420  , p=0.8375  , df=1
# parameter F test:         F=0.0416  , p=0.8386  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.9746  , p=0.0527  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=6.0594  , p=0.0483  , df=2
# likelihood ratio test: chi2=5.9936  , p=0.0499  , df=2
# parameter F test:         F=2.9746  , p=0.0527  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.1374  , p=0.0259  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=9.6589  , p=0.0217  , df=3
# likelihood ratio test: chi2=9.4926  , p=0.0234  , df=3
# parameter F test:         F=3.1374  , p=0.0259  , df_denom=267, df_num=3
# Granger causality test between 'Manufacturing Employment Index' and 'Advance Monthly Sales for retail & food services (Millions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0084  , p=0.9268  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=0.0085  , p=0.9264  , df=1
# likelihood ratio test: chi2=0.0085  , p=0.9264  , df=1
# parameter F test:         F=0.0084  , p=0.9268  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.0587  , p=0.0070  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=10.3048 , p=0.0058  , df=2
# likelihood ratio test: chi2=10.1164 , p=0.0064  , df=2
# parameter F test:         F=5.0587  , p=0.0070  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=3.6057  , p=0.0139  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=11.1008 , p=0.0112  , df=3
# likelihood ratio test: chi2=10.8818 , p=0.0124  , df=3
# parameter F test:         F=3.6057  , p=0.0139  , df_denom=267, df_num=3
# Granger causality test between 'Manufacturing Employment Index' and 'CPI':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0136  , p=0.9071  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=0.0138  , p=0.9065  , df=1
# likelihood ratio test: chi2=0.0138  , p=0.9065  , df=1
# parameter F test:         F=0.0136  , p=0.9071  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8929  , p=0.4107  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=1.8189  , p=0.4027  , df=2
# likelihood ratio test: chi2=1.8130  , p=0.4039  , df=2
# parameter F test:         F=0.8929  , p=0.4107  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.9130  , p=0.4351  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=2.8110  , p=0.4217  , df=3
# likelihood ratio test: chi2=2.7966  , p=0.4241  , df=3
# parameter F test:         F=0.9130  , p=0.4351  , df_denom=267, df_num=3
# Granger causality test between 'Services Employment Index' and 'Advance Monthly Sales for retail & food services (Millions of Dollars)':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.5158  , p=0.4733  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=0.5214  , p=0.4702  , df=1
# likelihood ratio test: chi2=0.5209  , p=0.4704  , df=1
# parameter F test:         F=0.5158  , p=0.4733  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# ssr based F test:         F=28.4421 , p=0.0000  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=57.9376 , p=0.0000  , df=2
# likelihood ratio test: chi2=52.5756 , p=0.0000  , df=2
# parameter F test:         F=28.4421 , p=0.0000  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=19.2236 , p=0.0000  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=59.1828 , p=0.0000  , df=3
# likelihood ratio test: chi2=53.5843 , p=0.0000  , df=3
# parameter F test:         F=19.2236 , p=0.0000  , df_denom=267, df_num=3
# Granger causality test between 'Services Employment Index' and 'CPI':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2501  , p=0.6174  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=0.2528  , p=0.6151  , df=1
# likelihood ratio test: chi2=0.2527  , p=0.6152  , df=1
# parameter F test:         F=0.2501  , p=0.6174  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.7611  , p=0.4681  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=1.5504  , p=0.4606  , df=2
# likelihood ratio test: chi2=1.5460  , p=0.4616  , df=2
# parameter F test:         F=0.7611  , p=0.4681  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.2983  , p=0.0779  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=7.0758  , p=0.0695  , df=3
# likelihood ratio test: chi2=6.9860  , p=0.0723  , df=3
# parameter F test:         F=2.2983  , p=0.0779  , df_denom=267, df_num=3
# Granger causality test between 'Advance Monthly Sales for retail & food services (Millions of Dollars)' and 'CPI':
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.7525  , p=0.1867  , df_denom=273, df_num=1
# ssr based chi2 test:   chi2=1.7718  , p=0.1832  , df=1
# likelihood ratio test: chi2=1.7661  , p=0.1839  , df=1
# parameter F test:         F=1.7525  , p=0.1867  , df_denom=273, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.9616  , p=0.3836  , df_denom=270, df_num=2
# ssr based chi2 test:   chi2=1.9589  , p=0.3755  , df=2
# likelihood ratio test: chi2=1.9519  , p=0.3768  , df=2
# parameter F test:         F=0.9616  , p=0.3836  , df_denom=270, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.8072  , p=0.4908  , df_denom=267, df_num=3
# ssr based chi2 test:   chi2=2.4851  , p=0.4780  , df=3
# likelihood ratio test: chi2=2.4739  , p=0.4800  , df=3
# parameter F test:         F=0.8072  , p=0.4908  , df_denom=267, df_num=3
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\Lib\site-packages\statsmodels\tsa\stattools.py:1488: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(

# %% [markdown]
# # Analysis on Election Year

# %%
df = pd.read_excel('unemployment_monthly levels.xlsx')

# Define U.S. election years (every 4 years starting from 1952)
election_years = [year for year in range(1952, 2024, 4)]

# Filter data for election years
df_election_years = df[df['Year'].isin(election_years)]

# Extract three months before and after November (Aug, Sep, Oct, Nov, Dec, Jan, Feb)
months_of_interest = ['Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Jan', 'Feb']

# Since Jan and Feb are from the next year, we need to handle this separately
df_interest = pd.DataFrame()
for year in election_years:
    temp = df[df['Year'] == year][['Year'] + months_of_interest[:5]] # Current year months
    temp_next_year = df[df['Year'] == year + 1][['Jan', 'Feb']] # Next year months
    temp_full = pd.concat([temp, temp_next_year], axis=1)
    df_interest = pd.concat([df_interest, temp_full], ignore_index=True)

print(df_interest.head())
# Out:
#      Year  Aug  Sep  Oct  Nov  Dec  Jan  Feb
# 0  1952.0  3.4  3.1  3.0  2.8  2.7  NaN  NaN
# 1     NaN  NaN  NaN  NaN  NaN  NaN  2.9  2.6
# 2  1956.0  4.1  3.9  3.9  4.3  4.2  NaN  NaN
# 3     NaN  NaN  NaN  NaN  NaN  NaN  4.2  3.9
# 4  1960.0  5.6  5.5  6.1  6.1  6.6  NaN  NaN

# %%
# Calculate the average unemployment rates for three months before and after the election month (November)
before_election = df_interest[['Aug', 'Sep', 'Oct']].mean(axis=1)
after_election = df_interest[['Nov', 'Dec', 'Jan', 'Feb']].mean(axis=1)

# Combine the results into a single DataFrame for easier comparison
average_unemployment = pd.DataFrame({'Year': df_interest['Year'], 'Before Election': before_election, 'After Election': after_election})

print(average_unemployment.head())
# Out:
#      Year  Before Election  After Election
# 0  1952.0         3.166667            2.75
# 1     NaN              NaN            2.75
# 2  1956.0         3.966667            4.25
# 3     NaN              NaN            4.05
# 4  1960.0         5.733333            6.35

# %%
# Remove rows with None values to clean up the data for plotting
average_unemployment_clean = average_unemployment.dropna()

# Plotting
plt.figure(figsize=(12, 6), facecolor='white')
plt.plot(average_unemployment_clean['Year'], average_unemployment_clean['Before Election'], label='Before Election', marker='o')
plt.plot(average_unemployment_clean['Year'], average_unemployment_clean['After Election'], label='After Election', marker='o')
plt.title('Average Unemployment Rates Around U.S. Election Years')
plt.xlabel('Year')
plt.ylabel('Average Unemployment Rate (%)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Inferences**
# *   In most cases the 13 out of 18 times the unemployment level seem to be less after the election than before the election
# *   Thus indicating that unemployment reduces after elections

# %%
# Calculate average unemployment rates for each year in the dataset
df['Average'] = df.iloc[:, 1:].mean(axis=1)

# Categorize years based on election year, year after election, and other years
df['Category'] = 'Other Years'
df.loc[df['Year'].isin(election_years), 'Category'] = 'Election Year'
df.loc[df['Year'].isin([year + 1 for year in election_years]), 'Category'] = 'Year After Election'

# Group by category and calculate average unemployment rate for each category
category_averages = df.groupby('Category')['Average'].mean().sort_values(ascending=False)

# Plotting
plt.figure(figsize=(10, 6), facecolor='white')
category_averages.plot(kind='bar', color=['#517AF1', '#F7897F', '#41C04A'])
plt.title('Average Unemployment Rates by Year Category')
plt.xlabel('Year Category')
plt.ylabel('Average Unemployment Rate (%)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# Comparing the average employment rates during the elction year, year after elction and other years it indicates that the unemployment was usually higher during the election year than the others.

# %%
# Calculate the average unemployment rate 6 months before and after the election month (November)
# Election month is November, so we consider May to October for before and December to May for after
# Load the data
file_path = 'unemployment_monthly levels.xlsx'
df = pd.read_excel(file_path)

# Election years
election_years = [year for year in range(1952, 2024, 4)]

# Calculate averages
six_month_avgs = []
for year in election_years:
    year_data = df[df['Year'] == year]
    avg_before = year_data[['May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct']].mean(axis=1).values[0]
    # For after, we need to handle the year transition
    if year + 1 in df['Year'].values:
        next_year_data = df[df['Year'] == year + 1]
        avg_after = next_year_data[['Dec', 'Jan', 'Feb', 'Mar', 'Apr', 'May']].mean(axis=1).values[0]
    else:
        avg_after = np.nan  # In case the next year's data is not available
    six_month_avgs.append({'Year': year, 'Before Election': avg_before, 'After Election': avg_after})

# Convert to DataFrame
six_month_avgs_df = pd.DataFrame(six_month_avgs)
print(six_month_avgs_df.head())
# Out:
#    Year  Before Election  After Election
# 0  1952         3.116667        2.966667
# 1  1956         4.150000        4.166667
# 2  1960         5.533333        6.750000
# 3  1964         5.066667        4.683333
# 4  1968         3.533333        3.416667

# %%
# Load the data from the Excel file
unemployment_data = pd.read_excel('unemployment_monthly levels.xlsx')

# Calculate the average unemployment rate for each year
unemployment_data['Average'] = unemployment_data.iloc[:, 1:].mean(axis=1)

# Define election years and categorize years
election_years = [1952, 1956, 1960, 1964, 1968, 1972, 1976, 1980, 1984, 1988, 1992, 1996, 2000, 2004, 2008, 2012, 2016, 2020]
unemployment_data['Year Category'] = 'Other Years'
unemployment_data.loc[unemployment_data['Year'].isin(election_years), 'Year Category'] = 'Election Year'
unemployment_data.loc[unemployment_data['Year'].isin(np.array(election_years) - 1), 'Year Category'] = 'Year Before Election'
unemployment_data.loc[unemployment_data['Year'].isin(np.array(election_years) + 1), 'Year Category'] = 'Year After Election'

# Set up the color mapping for each category
colors = {'Election Year': '#517AF1', 'Year Before Election': '#41C04A', 'Year After Election': '#F7897F'}

# Sort the data by average unemployment rate in descending order
sorted_data = unemployment_data.sort_values(by='Average', ascending=False)
# Create the bar chart with sorted data
plt.figure(figsize=(14, 7), facecolor='white')
for category, color in colors.items():
    subset = sorted_data[sorted_data['Year Category'] == category]
    plt.bar(subset['Year'], subset['Average'], color=color, label=category)

plt.title('Average Unemployment Rates by Year Category (Sorted)')
plt.xlabel('Year')
plt.ylabel('Average Unemployment Rate (%)')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %%
averages = []
for year in election_years:
    # Three months before
    if year in unemployment_data['Year'].values:
        three_months_before = unemployment_data.loc[unemployment_data['Year'] == year, 'Jul':'Sep'].mean().mean()
    else:
        three_months_before = np.nan  # Handle cases where the data for the year might not be available

    # Three months after
    if year in unemployment_data['Year'].values:
        three_months_after = unemployment_data.loc[unemployment_data['Year'] == year, 'Jan':'Mar'].mean().mean()
    else:
        three_months_after = np.nan  # Handle cases where the data for the year might not be available

    averages.append({'Year': year, 'Average 3 Months Before': three_months_before, 'Average 3 Months After': three_months_after})

# Convert to DataFrame
averages_df = pd.DataFrame(averages)

# Plotting
plt.figure(figsize=(14, 7), facecolor='white')
plt.bar(averages_df['Year']-0.2, averages_df['Average 3 Months Before'], width=0.4, label='3 Months Before Election', color='#517AF1')
plt.bar(averages_df['Year']+0.2, averages_df['Average 3 Months After'], width=0.4, label='3 Months After Election', color='#F7897F')
plt.title('Average Unemployment Rate 3 Months Before and 3 Months After Election Years')
plt.xlabel('Election Year')
plt.ylabel('Average Unemployment Rate (%)')
plt.xticks(election_years, rotation=45)
plt.legend()
plt.grid(True)
plt.show()
